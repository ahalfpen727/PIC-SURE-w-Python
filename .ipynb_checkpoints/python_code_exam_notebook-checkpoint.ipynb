# %% [markdown]
# # PIC-SURE API Biomedical Informatics Systems Analyst Code Test

# %% [markdown]
# ## Introduction
#
# A key component to this role is to help our team develop ways to enable research without exporting the data and to help users(mostly researchers) to use those functions of the API to perform research tasks. These problems are designed to test your proficiency in Python and your ability to think creatively about solving a problem in a new way.
#
# We will start with an introduction to the PIC-SURE API and introduce all of the basic operations that should be required to answer the code test.
#
# At any point if you wish to try things out, or to answer the code test challenges when you get to them, these JupyterHub features will be useful:
#
# This button in the toolbar above allows you to add a new cell after the selected cell : ![image.png](attachment:image.png)
#
# This dropdown in the toolbar above allows you to change the type of the selected cell : ![image-2.png](attachment:image-2.png)
#
# ### Because this is a code test and should not take you a long time to complete, we are not judging you on scientific or statistical rigor. The code test will be graded based on how you use the API to answer the challenge problems at the end of the notebook.

# %% [markdown]
# ## PIC-SURE python API
# ### What is PIC-SURE?
#
# <!--img src="./img/PIC-SURE_logo.png" width= "360px"> -->
#
# As part of the BioData Catalyst initiative, the Patient Information Commons Standard Unification of Research Elements (PIC-SURE) platform has been integrating clinical and genomic datasets from multiple TOPMed and TOPMed related studies funded by the National Heart Lung and Blood Institute (NHLBI).
#
# ### PIC-SURE Client Libraries
# Two sets of client libraries are avaialable for the PIC-SURE API, python and R, helping investigators to query the datasets using either of those languages.
#
# PIC-SURE is a larger project from which the R/python PIC-SURE API is only a single component. Among other things, PIC-SURE also offers a graphical user interface that allows researchers to explore variables across multiple studies, filter patient that match criteria, and create cohort from this interactive exploration.
#
# The python API is actively developed by the Avillach-Lab at Harvard Medical School.
#
# PIC-SURE API GitHub repo:
# * https://github.com/hms-dbmi/pic-sure-python-adapter-hpds
# * https://github.com/hms-dbmi/pic-sure-python-client

# %% [markdown]
#  -------

# %% [markdown]
# ### Packages installation
#
# Installation of the packages listed in the `requirements.txt` file, as well as the two components of the PIC-SURE API from GitHub, that is the PIC-SURE adapter and the PIC-SURE Client.

# %%
# %%bash
# pwd
# cat requirements.txt
# Out:
# /home/drew/Downloads/PIC-SURE
# numpy==1.16.4
# matplotlib>=3.1.1
# pandas>=0.25.3
# scipy>=1.3.1
# tqdm>=4.38.0
# statsmodels>=0.10.2

# %%
# !python3 -m pip install -r requirements.txt
# Out:
# Collecting numpy==1.16.4
#   Using cached numpy-1.16.4.zip (5.1 MB)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: pandas>=0.25.3 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 3)) (0.25.3)
# Requirement already satisfied: scipy>=1.3.1 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 4)) (1.3.3)
# Collecting tqdm>=4.38.0
#   Using cached tqdm-4.54.1-py2.py3-none-any.whl (69 kB)
# Requirement already satisfied: statsmodels>=0.10.2 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 6)) (0.11.1)
# Building wheels for collected packages: numpy
#   Building wheel for numpy (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-o6nr09jn/numpy/setup.py'"'"'; __file__='"'"'/tmp/pip-install-o6nr09jn/numpy/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-99m33ihu
#        cwd: /tmp/pip-install-o6nr09jn/numpy/
#   Complete output (332 lines):
#   Running from numpy source directory.
#   /tmp/pip-install-o6nr09jn/numpy/numpy/distutils/misc_util.py:476: SyntaxWarning: "is" with a literal. Did you mean "=="?
#     return is_string(s) and ('*' in s or '?' is s)
#   blas_opt_info:
#   blas_mkl_info:
#   customize UnixCCompiler
#     libraries mkl_rt not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#     NOT AVAILABLE
#
#   blis_info:
#   customize UnixCCompiler
#     libraries blis not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#     NOT AVAILABLE
#
#   openblas_info:
#   customize UnixCCompiler
#   customize UnixCCompiler
#     libraries openblas not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#     NOT AVAILABLE
#
#   atlas_3_10_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   customize UnixCCompiler
#     libraries tatlas not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu/atlas', '/usr/lib/x86_64-linux-gnu']
#     NOT AVAILABLE
#
#   atlas_3_10_blas_info:
#   customize UnixCCompiler
#     libraries satlas not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu/atlas', '/usr/lib/x86_64-linux-gnu']
#     NOT AVAILABLE
#
#   atlas_blas_threads_info:
#   Setting PTATLAS=ATLAS
#   customize UnixCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu/atlas', '/usr/lib/x86_64-linux-gnu']
#     NOT AVAILABLE
#
#   atlas_blas_info:
#   customize UnixCCompiler
#     libraries f77blas,cblas,atlas not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu/atlas', '/usr/lib/x86_64-linux-gnu']
#     NOT AVAILABLE
#
#   accelerate_info:
#     NOT AVAILABLE
#
#   /tmp/pip-install-o6nr09jn/numpy/numpy/distutils/system_info.py:639: UserWarning:
#       Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [atlas]) or by setting
#       the ATLAS environment variable.
#     self.calc_info()
#   blas_info:
#   customize UnixCCompiler
#     libraries blas not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#     NOT AVAILABLE
#
#   /tmp/pip-install-o6nr09jn/numpy/numpy/distutils/system_info.py:639: UserWarning:
#       Blas (http://www.netlib.org/blas/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [blas]) or by setting
#       the BLAS environment variable.
#     self.calc_info()
#   blas_src_info:
#     NOT AVAILABLE
#
#   /tmp/pip-install-o6nr09jn/numpy/numpy/distutils/system_info.py:639: UserWarning:
#       Blas (http://www.netlib.org/blas/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [blas_src]) or by setting
#       the BLAS_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   /bin/sh: 1: svnversion: not found
#   non-existing path in 'numpy/distutils': 'site.cfg'
#   lapack_opt_info:
#   lapack_mkl_info:
#   customize UnixCCompiler
#     libraries mkl_rt not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#     NOT AVAILABLE
#
#   openblas_lapack_info:
#   customize UnixCCompiler
#   customize UnixCCompiler
#     libraries openblas not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#     NOT AVAILABLE
#
#   openblas_clapack_info:
#   customize UnixCCompiler
#   customize UnixCCompiler
#     libraries openblas,lapack not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#     NOT AVAILABLE
#
#   atlas_3_10_threads_info:
#   Setting PTATLAS=ATLAS
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/local/lib
#   customize UnixCCompiler
#     libraries tatlas,tatlas not found in /usr/local/lib
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/lib
#   customize UnixCCompiler
#     libraries tatlas,tatlas not found in /usr/lib
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu/atlas
#   customize UnixCCompiler
#     libraries tatlas,tatlas not found in /usr/lib/x86_64-linux-gnu/atlas
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu
#   customize UnixCCompiler
#     libraries tatlas,tatlas not found in /usr/lib/x86_64-linux-gnu
#   <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#     NOT AVAILABLE
#
#   atlas_3_10_info:
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/local/lib
#   customize UnixCCompiler
#     libraries satlas,satlas not found in /usr/local/lib
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/lib
#   customize UnixCCompiler
#     libraries satlas,satlas not found in /usr/lib
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu/atlas
#   customize UnixCCompiler
#     libraries satlas,satlas not found in /usr/lib/x86_64-linux-gnu/atlas
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu
#   customize UnixCCompiler
#     libraries satlas,satlas not found in /usr/lib/x86_64-linux-gnu
#   <class 'numpy.distutils.system_info.atlas_3_10_info'>
#     NOT AVAILABLE
#
#   atlas_threads_info:
#   Setting PTATLAS=ATLAS
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/local/lib
#   customize UnixCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in /usr/local/lib
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/lib
#   customize UnixCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in /usr/lib
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu/atlas
#   customize UnixCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in /usr/lib/x86_64-linux-gnu/atlas
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu
#   customize UnixCCompiler
#     libraries ptf77blas,ptcblas,atlas not found in /usr/lib/x86_64-linux-gnu
#   <class 'numpy.distutils.system_info.atlas_threads_info'>
#     NOT AVAILABLE
#
#   atlas_info:
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/local/lib
#   customize UnixCCompiler
#     libraries f77blas,cblas,atlas not found in /usr/local/lib
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/lib
#   customize UnixCCompiler
#     libraries f77blas,cblas,atlas not found in /usr/lib
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu/atlas
#   customize UnixCCompiler
#     libraries f77blas,cblas,atlas not found in /usr/lib/x86_64-linux-gnu/atlas
#   customize UnixCCompiler
#     libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu
#   customize UnixCCompiler
#     libraries f77blas,cblas,atlas not found in /usr/lib/x86_64-linux-gnu
#   <class 'numpy.distutils.system_info.atlas_info'>
#     NOT AVAILABLE
#
#   lapack_info:
#   customize UnixCCompiler
#     libraries lapack not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#     NOT AVAILABLE
#
#   /tmp/pip-install-o6nr09jn/numpy/numpy/distutils/system_info.py:639: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [lapack]) or by setting
#       the LAPACK environment variable.
#     self.calc_info()
#   lapack_src_info:
#     NOT AVAILABLE
#
#   /tmp/pip-install-o6nr09jn/numpy/numpy/distutils/system_info.py:639: UserWarning:
#       Lapack (http://www.netlib.org/lapack/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#       the LAPACK_SRC environment variable.
#     self.calc_info()
#     NOT AVAILABLE
#
#   /usr/lib/python3.8/distutils/dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running config_cc
#   unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   build_src
#   building py_modules sources
#   creating build
#   creating build/src.linux-x86_64-3.8
#   creating build/src.linux-x86_64-3.8/numpy
#   creating build/src.linux-x86_64-3.8/numpy/distutils
#   building library "npymath" sources
#   get_default_fcompiler: matching types: '['gnu95', 'intel', 'lahey', 'pg', 'absoft', 'nag', 'vast', 'compaq', 'intele', 'intelem', 'gnu', 'g95', 'pathf95', 'nagfor']'
#   customize Gnu95FCompiler
#   Found executable /usr/bin/gfortran
#   customize Gnu95FCompiler
#   customize Gnu95FCompiler using config
#   C compiler: x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#   compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.8 -c'
#   x86_64-linux-gnu-gcc: _configtest.c
#   x86_64-linux-gnu-gcc -pthread _configtest.o -o _configtest
#   success!
#   removing: _configtest.c _configtest.o _configtest.o.d _configtest
#   C compiler: x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#   compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.8 -c'
#   x86_64-linux-gnu-gcc: _configtest.c
#   _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#       1 | int exp (void);
#         |     ^~~
#   _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#     +++ |+#include <math.h>
#       1 | int exp (void);
#   x86_64-linux-gnu-gcc -pthread _configtest.o -o _configtest
#   /usr/bin/ld: _configtest.o: in function `main':
#   /tmp/pip-install-o6nr09jn/numpy/_configtest.c:6: undefined reference to `exp'
#   collect2: error: ld returned 1 exit status
#   failure.
#   removing: _configtest.c _configtest.o _configtest.o.d
#   C compiler: x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#   compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.8 -c'
#   x86_64-linux-gnu-gcc: _configtest.c
#   _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#       1 | int exp (void);
#         |     ^~~
#   _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#     +++ |+#include <math.h>
#       1 | int exp (void);
#   x86_64-linux-gnu-gcc -pthread _configtest.o -lm -o _configtest
#   success!
#   removing: _configtest.c _configtest.o _configtest.o.d _configtest
#   creating build/src.linux-x86_64-3.8/numpy/core
#   creating build/src.linux-x86_64-3.8/numpy/core/src
#   creating build/src.linux-x86_64-3.8/numpy/core/src/npymath
#   conv_template:> build/src.linux-x86_64-3.8/numpy/core/src/npymath/npy_math_internal.h
#     adding 'build/src.linux-x86_64-3.8/numpy/core/src/npymath' to include_dirs.
#   conv_template:> build/src.linux-x86_64-3.8/numpy/core/src/npymath/ieee754.c
#   conv_template:> build/src.linux-x86_64-3.8/numpy/core/src/npymath/npy_math_complex.c
#   None - nothing done with h_files = ['build/src.linux-x86_64-3.8/numpy/core/src/npymath/npy_math_internal.h']
#   building library "npysort" sources
#   creating build/src.linux-x86_64-3.8/numpy/core/src/common
#   conv_template:> build/src.linux-x86_64-3.8/numpy/core/src/common/npy_sort.h
#     adding 'build/src.linux-x86_64-3.8/numpy/core/src/common' to include_dirs.
#   creating build/src.linux-x86_64-3.8/numpy/core/src/npysort
#   conv_template:> build/src.linux-x86_64-3.8/numpy/core/src/npysort/quicksort.c
#   conv_template:> build/src.linux-x86_64-3.8/numpy/core/src/npysort/mergesort.c
#   conv_template:> build/src.linux-x86_64-3.8/numpy/core/src/npysort/heapsort.c
#   conv_template:> build/src.linux-x86_64-3.8/numpy/core/src/common/npy_partition.h
#   conv_template:> build/src.linux-x86_64-3.8/numpy/core/src/npysort/selection.c
#   conv_template:> build/src.linux-x86_64-3.8/numpy/core/src/common/npy_binsearch.h
#   conv_template:> build/src.linux-x86_64-3.8/numpy/core/src/npysort/binsearch.c
#   None - nothing done with h_files = ['build/src.linux-x86_64-3.8/numpy/core/src/common/npy_sort.h', 'build/src.linux-x86_64-3.8/numpy/core/src/common/npy_partition.h', 'build/src.linux-x86_64-3.8/numpy/core/src/common/npy_binsearch.h']
#   building extension "numpy.core._dummy" sources
#   Generating build/src.linux-x86_64-3.8/numpy/core/include/numpy/config.h
#   C compiler: x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#   compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.8 -c'
#   x86_64-linux-gnu-gcc: _configtest.c
#   _configtest.c:1:10: fatal error: Python.h: No such file or directory
#       1 | #include <Python.h>
#         |          ^~~~~~~~~~
#   compilation terminated.
#   failure.
#   removing: _configtest.c _configtest.o
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-o6nr09jn/numpy/setup.py", line 415, in <module>
#       setup_package()
#     File "/tmp/pip-install-o6nr09jn/numpy/setup.py", line 407, in setup_package
#       setup(**metadata)
#     File "/tmp/pip-install-o6nr09jn/numpy/numpy/distutils/core.py", line 171, in setup
#       return old_setup(**new_attr)
#     File "/usr/lib/python3/dist-packages/setuptools/__init__.py", line 144, in setup
#       return distutils.core.setup(**attrs)
#     File "/usr/lib/python3.8/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/usr/lib/python3.8/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/usr/lib/python3.8/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/usr/lib/python3/dist-packages/wheel/bdist_wheel.py", line 223, in run
#       self.run_command('build')
#     File "/usr/lib/python3.8/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/usr/lib/python3.8/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/tmp/pip-install-o6nr09jn/numpy/numpy/distutils/command/build.py", line 47, in run
#       old_build.run(self)
#     File "/usr/lib/python3.8/distutils/command/build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "/usr/lib/python3.8/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/usr/lib/python3.8/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/tmp/pip-install-o6nr09jn/numpy/numpy/distutils/command/build_src.py", line 148, in run
#       self.build_sources()
#     File "/tmp/pip-install-o6nr09jn/numpy/numpy/distutils/command/build_src.py", line 165, in build_sources
#       self.build_extension_sources(ext)
#     File "/tmp/pip-install-o6nr09jn/numpy/numpy/distutils/command/build_src.py", line 322, in build_extension_sources
#       sources = self.generate_sources(sources, ext)
#     File "/tmp/pip-install-o6nr09jn/numpy/numpy/distutils/command/build_src.py", line 375, in generate_sources
#       source = func(extension, build_dir)
#     File "numpy/core/setup.py", line 423, in generate_config_h
#       moredefs, ignored = cocache.check_types(config_cmd, ext, build_dir)
#     File "numpy/core/setup.py", line 47, in check_types
#       out = check_types(*a, **kw)
#     File "numpy/core/setup.py", line 279, in check_types
#       raise SystemError(
#   SystemError: Cannot compile 'Python.h'. Perhaps you need to install python-dev|python-devel.
#   ----------------------------------------
#   ERROR: Failed building wheel for numpy
#   Running setup.py clean for numpy
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-o6nr09jn/numpy/setup.py'"'"'; __file__='"'"'/tmp/pip-install-o6nr09jn/numpy/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#        cwd: /tmp/pip-install-o6nr09jn/numpy
#   Complete output (10 lines):
#   Running from numpy source directory.
#
#   `setup.py clean` is not supported, use one of the following instead:
#
#     - `git clean -xdf` (cleans all files)
#     - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                         files that aren't checked into the git repo)
#
#   Add `--force` to your command to use it anyway if you must (unsupported).
#
#   ----------------------------------------
#   ERROR: Failed cleaning build dir for numpy
# Failed to build numpy
# Installing collected packages: numpy, tqdm
#     Running setup.py install for numpy ... error
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-o6nr09jn/numpy/setup.py'"'"'; __file__='"'"'/tmp/pip-install-o6nr09jn/numpy/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-g88s3rjv/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /home/drew/.local/include/python3.8/numpy
#          cwd: /tmp/pip-install-o6nr09jn/numpy/
#     Complete output (323 lines):
#     Running from numpy source directory.
#
#     Note: if you need reliable uninstall behavior, then install
#     with pip instead of using `setup.py install`:
#
#       - `pip install .`       (from a git repo or downloaded source
#                                release)
#       - `pip install numpy`   (last NumPy release on PyPi)
#
#
#     blas_opt_info:
#     blas_mkl_info:
#     customize UnixCCompiler
#       libraries mkl_rt not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#       NOT AVAILABLE
#
#     blis_info:
#     customize UnixCCompiler
#       libraries blis not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#       NOT AVAILABLE
#
#     openblas_info:
#     customize UnixCCompiler
#     customize UnixCCompiler
#       libraries openblas not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     customize UnixCCompiler
#       libraries tatlas not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu/atlas', '/usr/lib/x86_64-linux-gnu']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#     customize UnixCCompiler
#       libraries satlas not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu/atlas', '/usr/lib/x86_64-linux-gnu']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     customize UnixCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu/atlas', '/usr/lib/x86_64-linux-gnu']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#     customize UnixCCompiler
#       libraries f77blas,cblas,atlas not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu/atlas', '/usr/lib/x86_64-linux-gnu']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     /tmp/pip-install-o6nr09jn/numpy/numpy/distutils/system_info.py:639: UserWarning:
#         Atlas (http://math-atlas.sourceforge.net/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [atlas]) or by setting
#         the ATLAS environment variable.
#       self.calc_info()
#     blas_info:
#     customize UnixCCompiler
#       libraries blas not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#       NOT AVAILABLE
#
#     /tmp/pip-install-o6nr09jn/numpy/numpy/distutils/system_info.py:639: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       self.calc_info()
#     blas_src_info:
#       NOT AVAILABLE
#
#     /tmp/pip-install-o6nr09jn/numpy/numpy/distutils/system_info.py:639: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     /bin/sh: 1: svnversion: not found
#     non-existing path in 'numpy/distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#     customize UnixCCompiler
#       libraries mkl_rt not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     customize UnixCCompiler
#     customize UnixCCompiler
#       libraries openblas not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#     customize UnixCCompiler
#     customize UnixCCompiler
#       libraries openblas,lapack not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries tatlas,tatlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib
#     customize UnixCCompiler
#       libraries tatlas,tatlas not found in /usr/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu/atlas
#     customize UnixCCompiler
#       libraries tatlas,tatlas not found in /usr/lib/x86_64-linux-gnu/atlas
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu
#     customize UnixCCompiler
#       libraries tatlas,tatlas not found in /usr/lib/x86_64-linux-gnu
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries satlas,satlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib
#     customize UnixCCompiler
#       libraries satlas,satlas not found in /usr/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu/atlas
#     customize UnixCCompiler
#       libraries satlas,satlas not found in /usr/lib/x86_64-linux-gnu/atlas
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu
#     customize UnixCCompiler
#       libraries satlas,satlas not found in /usr/lib/x86_64-linux-gnu
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib
#     customize UnixCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in /usr/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu/atlas
#     customize UnixCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in /usr/lib/x86_64-linux-gnu/atlas
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu
#     customize UnixCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in /usr/lib/x86_64-linux-gnu
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries f77blas,cblas,atlas not found in /usr/local/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib
#     customize UnixCCompiler
#       libraries f77blas,cblas,atlas not found in /usr/lib
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu/atlas
#     customize UnixCCompiler
#       libraries f77blas,cblas,atlas not found in /usr/lib/x86_64-linux-gnu/atlas
#     customize UnixCCompiler
#       libraries lapack_atlas not found in /usr/lib/x86_64-linux-gnu
#     customize UnixCCompiler
#       libraries f77blas,cblas,atlas not found in /usr/lib/x86_64-linux-gnu
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#     customize UnixCCompiler
#       libraries lapack not found in ['/usr/local/lib', '/usr/lib', '/usr/lib/x86_64-linux-gnu']
#       NOT AVAILABLE
#
#     /tmp/pip-install-o6nr09jn/numpy/numpy/distutils/system_info.py:639: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       self.calc_info()
#     lapack_src_info:
#       NOT AVAILABLE
#
#     /tmp/pip-install-o6nr09jn/numpy/numpy/distutils/system_info.py:639: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     /usr/lib/python3.8/distutils/dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running install
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     building library "npymath" sources
#     get_default_fcompiler: matching types: '['gnu95', 'intel', 'lahey', 'pg', 'absoft', 'nag', 'vast', 'compaq', 'intele', 'intelem', 'gnu', 'g95', 'pathf95', 'nagfor']'
#     customize Gnu95FCompiler
#     Found executable /usr/bin/gfortran
#     customize Gnu95FCompiler
#     customize Gnu95FCompiler using config
#     C compiler: x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#     compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.8 -c'
#     x86_64-linux-gnu-gcc: _configtest.c
#     x86_64-linux-gnu-gcc -pthread _configtest.o -o _configtest
#     success!
#     removing: _configtest.c _configtest.o _configtest.o.d _configtest
#     C compiler: x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#     compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.8 -c'
#     x86_64-linux-gnu-gcc: _configtest.c
#     _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#         1 | int exp (void);
#           |     ^~~
#     _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#       +++ |+#include <math.h>
#         1 | int exp (void);
#     x86_64-linux-gnu-gcc -pthread _configtest.o -o _configtest
#     /usr/bin/ld: _configtest.o: in function `main':
#     /tmp/pip-install-o6nr09jn/numpy/_configtest.c:6: undefined reference to `exp'
#     collect2: error: ld returned 1 exit status
#     failure.
#     removing: _configtest.c _configtest.o _configtest.o.d
#     C compiler: x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#     compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.8 -c'
#     x86_64-linux-gnu-gcc: _configtest.c
#     _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#         1 | int exp (void);
#           |     ^~~
#     _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#       +++ |+#include <math.h>
#         1 | int exp (void);
#     x86_64-linux-gnu-gcc -pthread _configtest.o -lm -o _configtest
#     success!
#     removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       adding 'build/src.linux-x86_64-3.8/numpy/core/src/npymath' to include_dirs.
#     None - nothing done with h_files = ['build/src.linux-x86_64-3.8/numpy/core/src/npymath/npy_math_internal.h']
#     building library "npysort" sources
#       adding 'build/src.linux-x86_64-3.8/numpy/core/src/common' to include_dirs.
#     None - nothing done with h_files = ['build/src.linux-x86_64-3.8/numpy/core/src/common/npy_sort.h', 'build/src.linux-x86_64-3.8/numpy/core/src/common/npy_partition.h', 'build/src.linux-x86_64-3.8/numpy/core/src/common/npy_binsearch.h']
#     building extension "numpy.core._dummy" sources
#     Generating build/src.linux-x86_64-3.8/numpy/core/include/numpy/config.h
#     C compiler: x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC
#
#     compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/usr/include/python3.8 -c'
#     x86_64-linux-gnu-gcc: _configtest.c
#     _configtest.c:1:10: fatal error: Python.h: No such file or directory
#         1 | #include <Python.h>
#           |          ^~~~~~~~~~
#     compilation terminated.
#     failure.
#     removing: _configtest.c _configtest.o
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-o6nr09jn/numpy/setup.py", line 415, in <module>
#         setup_package()
#       File "/tmp/pip-install-o6nr09jn/numpy/setup.py", line 407, in setup_package
#         setup(**metadata)
#       File "/tmp/pip-install-o6nr09jn/numpy/numpy/distutils/core.py", line 171, in setup
#         return old_setup(**new_attr)
#       File "/usr/lib/python3/dist-packages/setuptools/__init__.py", line 144, in setup
#         return distutils.core.setup(**attrs)
#       File "/usr/lib/python3.8/distutils/core.py", line 148, in setup
#         dist.run_commands()
#       File "/usr/lib/python3.8/distutils/dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "/usr/lib/python3.8/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/tmp/pip-install-o6nr09jn/numpy/numpy/distutils/command/install.py", line 62, in run
#         r = self.setuptools_run()
#       File "/tmp/pip-install-o6nr09jn/numpy/numpy/distutils/command/install.py", line 36, in setuptools_run
#         return distutils_install.run(self)
#       File "/usr/lib/python3.8/distutils/command/install.py", line 589, in run
#         self.run_command('build')
#       File "/usr/lib/python3.8/distutils/cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "/usr/lib/python3.8/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/tmp/pip-install-o6nr09jn/numpy/numpy/distutils/command/build.py", line 47, in run
#         old_build.run(self)
#       File "/usr/lib/python3.8/distutils/command/build.py", line 135, in run
#         self.run_command(cmd_name)
#       File "/usr/lib/python3.8/distutils/cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "/usr/lib/python3.8/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/tmp/pip-install-o6nr09jn/numpy/numpy/distutils/command/build_src.py", line 148, in run
#         self.build_sources()
#       File "/tmp/pip-install-o6nr09jn/numpy/numpy/distutils/command/build_src.py", line 165, in build_sources
#         self.build_extension_sources(ext)
#       File "/tmp/pip-install-o6nr09jn/numpy/numpy/distutils/command/build_src.py", line 322, in build_extension_sources
#         sources = self.generate_sources(sources, ext)
#       File "/tmp/pip-install-o6nr09jn/numpy/numpy/distutils/command/build_src.py", line 375, in generate_sources
#         source = func(extension, build_dir)
#       File "numpy/core/setup.py", line 423, in generate_config_h
#         moredefs, ignored = cocache.check_types(config_cmd, ext, build_dir)
#       File "numpy/core/setup.py", line 47, in check_types
#         out = check_types(*a, **kw)
#       File "numpy/core/setup.py", line 279, in check_types
#         raise SystemError(
#     SystemError: Cannot compile 'Python.h'. Perhaps you need to install python-dev|python-devel.
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-o6nr09jn/numpy/setup.py'"'"'; __file__='"'"'/tmp/pip-install-o6nr09jn/numpy/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-g88s3rjv/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /home/drew/.local/include/python3.8/numpy Check the logs for full command output.

# %%
# !pip install --upgrade pip
# !pip install git+https://github.com/hms-dbmi/pic-sure-python-client.git    
# !pip install git+https://github.com/hms-dbmi/pic-sure-python-adapter-hpds.git

# %%
# !cat https://github.com/hms-dbmi/pic-sure-python-adapter-hpds/blob/master/requirements_dev.txt
#!{sys.executable} -m pip install -r requirements.txt
# !{sys.executable} -m pip install -r https://github.com/hms-dbmi/pic-sure-python-adapter-hpds/blob/master/requirements_dev.txt
# Out:
# cat: 'https://github.com/hms-dbmi/pic-sure-python-adapter-hpds/blob/master/requirements_dev.txt': No such file or directory
# ERROR: Invalid requirement: '<!DOCTYPE html>' (from line 7 of https://github.com/hms-dbmi/pic-sure-python-adapter-hpds/blob/master/requirements_dev.txt)

# %%
import sys
sys.path
# !{sys.executable} -m pip install --upgrade --force-reinstall git+https://github.com/hms-dbmi/pic-sure-python-adapter-hpds.git
# !{sys.executable} -m pip install --upgrade --force-reinstall git+https://github.com/hms-dbmi/pic-sure-python-client.git
# Out:
# Collecting git+https://github.com/hms-dbmi/pic-sure-python-adapter-hpds.git
#   Cloning https://github.com/hms-dbmi/pic-sure-python-adapter-hpds.git to /tmp/pip-req-build-la3_p5zz
# Collecting httplib2
#   Using cached httplib2-0.18.1-py3-none-any.whl (95 kB)
# Building wheels for collected packages: PicSureHpdsLib
#   Building wheel for PicSureHpdsLib (setup.py) ... done
#   Created wheel for PicSureHpdsLib: filename=PicSureHpdsLib-0.9.0-py2.py3-none-any.whl size=21879 sha256=4ee51010ff3d153979eaa3addf6f1f9d034504e92dd3a346f4c9a7a978ef0cd1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l177v297/wheels/e8/35/43/484d5d574661fc4a2c5b083551bc3c7254695764ed17ce397e
# Successfully built PicSureHpdsLib
# Installing collected packages: httplib2, PicSureHpdsLib
#   Attempting uninstall: httplib2
#     Found existing installation: httplib2 0.18.1
#     Uninstalling httplib2-0.18.1:
#       Successfully uninstalled httplib2-0.18.1
#   Attempting uninstall: PicSureHpdsLib
#     Found existing installation: PicSureHpdsLib 0.9.0
#     Uninstalling PicSureHpdsLib-0.9.0:
#       Successfully uninstalled PicSureHpdsLib-0.9.0
# Successfully installed PicSureHpdsLib-0.9.0 httplib2-0.18.1
# Collecting git+https://github.com/hms-dbmi/pic-sure-python-client.git
#   Cloning https://github.com/hms-dbmi/pic-sure-python-client.git to /tmp/pip-req-build-0o98orbl
# Building wheels for collected packages: PicSureClient
#   Building wheel for PicSureClient (setup.py) ... done
#   Created wheel for PicSureClient: filename=PicSureClient-0.1.0-py2.py3-none-any.whl size=10149 sha256=07ca3d2fc309ccd710fea8ae4ede70fef7172c02bcfaa363269b8ce11eb971d8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8nebanlb/wheels/2f/61/65/c5af5ad47fa6a9e191522e1ae06d74c08b05c91a76a1c3d120
# Successfully built PicSureClient
# Installing collected packages: PicSureClient
#   Attempting uninstall: PicSureClient
#     Found existing installation: PicSureClient 0.1.0
#     Uninstalling PicSureClient-0.1.0:
#       Successfully uninstalled PicSureClient-0.1.0
# Successfully installed PicSureClient-0.1.0

# %% [markdown]
# Import all the external dependencies, as well as user-defined functions stored in the `python_lib` folder

# %%
import json
from pprint import pprint

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from scipy import stats

import PicSureHpdsLib
import PicSureClient

from python_lib.utils import get_multiIndex_variablesDict, joining_variablesDict_onCol

# %% [markdown]
# ##### Setting the display parameter for tables and plots

# %%
# Pandas DataFrame display options
pd.set_option("max.rows", 435)

# Matplotlib parameters options
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
fig_size[0] = 14
fig_size[1] = 8
plt.rcParams["figure.figsize"] = fig_size

font = {'weight' : 'bold',
        'size'   : 12}

plt.rc('font', **font)

# %% [markdown]
# ## Connecting to a PIC-SURE resource

# %% [markdown]
# Several information are required to get access to data through the PIC-SURE API: a network URL, a resource id, and a user-specific security token.

# %%
PICSURE_network_URL = "https://3.236.133.248/picsure"
resource_id = "d39ae852-e22e-45d5-a7b2-6056ac54580f"
token_file = "../token.txt"

# %%
with open(token_file, "r") as f:
    my_token = f.read()

# %%
client = PicSureClient.Client()
connection = client.connect(PICSURE_network_URL, my_token, True)
adapter = PicSureHpdsLib.Adapter(connection)
resource = adapter.useResource(resource_id)
# Out:
# +=========================================================================================+
# |        [ WARNING ] you are specifying that you WANT to allow self-signed SSL            |
# |        certificates to be acceptable for connections.  This may be useful for           |
# |        working in a development environment or on systems that host public              |
# |        data.  BEST SECURITY PRACTICES ARE THAT IF YOU ARE WORKING WITH SENSITIVE        |
# |        DATA THEN ALL SSL CERTS BY THOSE EVIRONMENTS SHOULD NOT BE SELF-SIGNED.          |
# +=========================================================================================+
#
# +--------------------------------------+------------------------------------------------------
# |  Resource UUID                       |  Resource Name
# +--------------------------------------+------------------------------------------------------
# | d39ae852-e22e-45d5-a7b2-6056ac54580f
# +--------------------------------------+------------------------------------------------------

# %% [markdown]
# Two objects are created here: a `connection` and a `resource` object.
#
# As we will only be using one single resource, **the `resource` object is actually the only one we will need to proceed with data analysis hereafter**.
#
# It is connected to the specific data source ID we specified, and enables to query and retrieve data from this database.

# %% [markdown]
# ## Getting help with the PIC-SURE API

# %% [markdown]
# Each object exposed by the PicSureHpdsLib library got a `help()` method. Calling it will without parameters print out an information about functionalities of this object.

# %%
resource.help()
# Out:
#         [HELP] PicSureHpdsLib.useResource(resource_uuid)
#             .dictionary()       Used to access data dictionary of the resource
#             .query()            Used to query against data in the resource
#             .retrieveQueryResults(query_uuid) returns the results of an asynchronous query that has already been submitted to PICSURE
#
#         [ENVIRONMENT]
#               Endpoint URL: https://3.236.133.248/picsure/
#              Resource UUID: d39ae852-e22e-45d5-a7b2-6056ac54580f
# '\\questionnaire\\occupation\\occupation_midmanage\\'

# %%
quest_disease_dictionary_search
plain_variablesDict= resource.dictionary().find()
VariablesDict = plain_variablesDict.DataFrame()
variablesDict = get_multiIndex_variablesDict(VariablesDict)

mask_age = variablesDict.index.get_level_values(1) == "AGE"
#age_disease_variables = lung_disease_variables.loc[mask_age]
lung_disease_variables.count

mask_disease = variablesDict.index.get_level_values(1) == "disease"
mask_age = variablesDict.index.get_level_values(1) == "AGE"
mask_current_asthma = variablesDict.index.get_level_values(2) == "Current asthma?"
mask_ever_asthma = variablesDict.index.get_level_values(2) == "Ever asthma?"
mask_lung_cancer = variablesDict.index.get_level_values(2) == "lung_cancer_self_report"
lung_disease_variables = variablesDict.loc[mask_current_asthma | mask_ever_asthma | mask_lung_cancer,:]
lung_disease_variables

# %%
#bmidf = resource.dictionary().find("BMI").DataFrame()
bmidf.DataFrame()
plain_variablesDict = resource.dictionary().find().DataFrame()
variablesDict = get_multiIndex_variablesDict(plain_variablesDict)
mask_study = variablesDict.index.get_level_values(2) == "Body Mass Index"
mask_transplant = variablesDict.index.get_level_values(2) == "BP"
medication_history_variables = variablesDict.loc[~mask_study,:]
medication_history_variables.transpose
age_disease_variables = variablesDict.loc[~mask_transplant]
age_disease_variables
# Out:
#                                                                                                        simplified_name  \
# level_0       level_1         level_2                                 level_3
# SUBJECT_ID    NaN             NaN                                     NaN                                   SUBJECT_ID
# demographics  AGE             NaN                                     NaN                                          AGE
#               DMDBORN         NaN                                     NaN                                      DMDBORN
#               DMDMARTL        NaN                                     NaN                                     DMDMARTL
#               INDFMPIR        NaN                                     NaN                                     INDFMPIR
# ...                                                                                                                ...
# questionnaire supplement use  VITAMIN_C_Unknown                       NaN                            VITAMIN_C_Unknown
#                               VITAMIN_C_mg                            NaN                                 VITAMIN_C_mg
#                               total supplement count                  NaN                       total supplement count
#               viral infection Doctor ever told you had genital herpes NaN      Doctor ever told you had genital herpes
#                               Doctor ever told you had genital warts  NaN       Doctor ever told you had genital warts
#
#                                                                                                                             name  \
# level_0       level_1         level_2                                 level_3
# SUBJECT_ID    NaN             NaN                                     NaN                                            SUBJECT_ID\
# demographics  AGE             NaN                                     NaN                                     \demographics\AGE\
#               DMDBORN         NaN                                     NaN                                 \demographics\DMDBORN\
#               DMDMARTL        NaN                                     NaN                                \demographics\DMDMARTL\
#               INDFMPIR        NaN                                     NaN                                \demographics\INDFMPIR\
# ...                                                                                                                          ...
# questionnaire supplement use  VITAMIN_C_Unknown                       NaN       \questionnaire\supplement use\VITAMIN_C_Unknown\
#                               VITAMIN_C_mg                            NaN            \questionnaire\supplement use\VITAMIN_C_mg\
#                               total supplement count                  NaN      \questionnaire\supplement use\total supplement...
#               viral infection Doctor ever told you had genital herpes NaN      \questionnaire\viral infection\Doctor ever tol...
#                               Doctor ever told you had genital warts  NaN      \questionnaire\viral infection\Doctor ever tol...
#
#                                                                                observationCount  \
# level_0       level_1         level_2                                 level_3
# SUBJECT_ID    NaN             NaN                                     NaN                  9999
# demographics  AGE             NaN                                     NaN                  9999
#               DMDBORN         NaN                                     NaN                  9992
#               DMDMARTL        NaN                                     NaN                  6458
#               INDFMPIR        NaN                                     NaN                  9199
# ...                                                                                         ...
# questionnaire supplement use  VITAMIN_C_Unknown                       NaN                  5059
#                               VITAMIN_C_mg                            NaN                  9872
#                               total supplement count                  NaN                  9982
#               viral infection Doctor ever told you had genital herpes NaN                  2516
#                               Doctor ever told you had genital warts  NaN                  2515
#
#                                                                                categorical  \
# level_0       level_1         level_2                                 level_3
# SUBJECT_ID    NaN             NaN                                     NaN            False
# demographics  AGE             NaN                                     NaN            False
#               DMDBORN         NaN                                     NaN            False
#               DMDMARTL        NaN                                     NaN            False
#               INDFMPIR        NaN                                     NaN            False
# ...                                                                                    ...
# questionnaire supplement use  VITAMIN_C_Unknown                       NaN            False
#                               VITAMIN_C_mg                            NaN            False
#                               total supplement count                  NaN            False
#               viral infection Doctor ever told you had genital herpes NaN             True
#                               Doctor ever told you had genital warts  NaN             True
#
#                                                                               categoryValues  \
# level_0       level_1         level_2                                 level_3
# SUBJECT_ID    NaN             NaN                                     NaN               None
# demographics  AGE             NaN                                     NaN               None
#               DMDBORN         NaN                                     NaN               None
#               DMDMARTL        NaN                                     NaN               None
#               INDFMPIR        NaN                                     NaN               None
# ...                                                                                      ...
# questionnaire supplement use  VITAMIN_C_Unknown                       NaN               None
#                               VITAMIN_C_mg                            NaN               None
#                               total supplement count                  NaN               None
#               viral infection Doctor ever told you had genital herpes NaN          [No, Yes]
#                               Doctor ever told you had genital warts  NaN          [No, Yes]
#
#                                                                                nb_modalities  \
# level_0       level_1         level_2                                 level_3
# SUBJECT_ID    NaN             NaN                                     NaN                NaN
# demographics  AGE             NaN                                     NaN                NaN
#               DMDBORN         NaN                                     NaN                NaN
#               DMDMARTL        NaN                                     NaN                NaN
#               INDFMPIR        NaN                                     NaN                NaN
# ...                                                                                      ...
# questionnaire supplement use  VITAMIN_C_Unknown                       NaN                NaN
#                               VITAMIN_C_mg                            NaN                NaN
#                               total supplement count                  NaN                NaN
#               viral infection Doctor ever told you had genital herpes NaN                2.0
#                               Doctor ever told you had genital warts  NaN                2.0
#
#                                                                                min  \
# level_0       level_1         level_2                                 level_3
# SUBJECT_ID    NaN             NaN                                     NaN      2.0
# demographics  AGE             NaN                                     NaN      0.0
#               DMDBORN         NaN                                     NaN      1.0
#               DMDMARTL        NaN                                     NaN      1.0
#               INDFMPIR        NaN                                     NaN      0.0
# ...                                                                            ...
# questionnaire supplement use  VITAMIN_C_Unknown                       NaN      0.0
#                               VITAMIN_C_mg                            NaN      0.0
#                               total supplement count                  NaN      0.0
#               viral infection Doctor ever told you had genital herpes NaN      NaN
#                               Doctor ever told you had genital warts  NaN      NaN
#
#                                                                                         max  \
# level_0       level_1         level_2                                 level_3
# SUBJECT_ID    NaN             NaN                                     NaN      41472.000000
# demographics  AGE             NaN                                     NaN         85.000000
#               DMDBORN         NaN                                     NaN          3.000000
#               DMDMARTL        NaN                                     NaN         77.000000
#               INDFMPIR        NaN                                     NaN          5.000000
# ...                                                                                     ...
# questionnaire supplement use  VITAMIN_C_Unknown                       NaN          0.933333
#                               VITAMIN_C_mg                            NaN      29997.000000
#                               total supplement count                  NaN         19.000000
#               viral infection Doctor ever told you had genital herpes NaN               NaN
#                               Doctor ever told you had genital warts  NaN               NaN
#
#                                                                               HpdsDataType
# level_0       level_1         level_2                                 level_3
# SUBJECT_ID    NaN             NaN                                     NaN       phenotypes
# demographics  AGE             NaN                                     NaN       phenotypes
#               DMDBORN         NaN                                     NaN       phenotypes
#               DMDMARTL        NaN                                     NaN       phenotypes
#               INDFMPIR        NaN                                     NaN       phenotypes
# ...                                                                                    ...
# questionnaire supplement use  VITAMIN_C_Unknown                       NaN       phenotypes
#                               VITAMIN_C_mg                            NaN       phenotypes
#                               total supplement count                  NaN       phenotypes
#               viral infection Doctor ever told you had genital herpes NaN       phenotypes
#                               Doctor ever told you had genital warts  NaN       phenotypes
#
# [1159 rows x 9 columns]

# %% [markdown]
# For instance, this output tells us that this `resource` object has 3 methods, and it gives a quick definition of those methods.

# %% [markdown]
# ## Using the *variables dictionnary*

# %% [markdown]
# Once a connection to the desired resource has been established, we first need to get a knowledge of which variables are available in the database. To this end, we will use the `dictionary` method of the `resource` object.

# %% [markdown]
# Variables in PIC-SURE are queried using `concept paths`. A concept path is an identifier for a variable. It represents a path in the hierarchy of concepts. Some concept paths are derived from well known ontologies, other just reflect the organization of data within a particular study. Each level of organization in a concept path is marked by a `\` character. Because this character is commonly used to escape other characters in most programming language including Python and R, any `\` instances need to be escaped with another `\` to tell the language interpreter that a literal `\` was intended.
#
# This is a concept path in our dataset: `\demographics\AGE\`
#
# If you were to use this concept path in a query you would have to escape the backslashes as dictated by Python and R, as well as most every other programming language.
#
# This would be a valid way to reference that concept path in a Python or R string: "\\demographics\\AGE\\"
#
# To find concept paths in PIC-SURE we use the `dictionary` API object.

# %% [markdown]
# A `dictionary` instance enables to retrieve matching records by searching for a specific term, or to retrieve information about all the available variables, using the `find()` method. For instance, looking for variables containing the term `AGE` in their names is done this way:

# %%
#len(quest_disease_dictionary_search.keys())
quest_dis=quest_disease_dictionary_search
quest_dis

# %% [markdown]
# Subsequently, objects created by the `dictionary.find` method expose the search results via 4 different methods: `.count()`, `.keys()`, `.entries()`, and `.DataFrame()`.

# %%
copdgene_dic = resource.dictionary().find("disease").DataFrame()
consent_dic = resource.dictionary().find("AGE").DataFrame()

plain_variablesDict = resource.dictionary().find("Disease").DataFrame()
plain_variablesDict = resource.dictionary().find().DataFrame()
variablesDict = get_multiIndex_variablesDict(plain_variablesDict)
mask_age = variablesDict.index.get_level_values(1) == "AGE"
mask_disease = variablesDict.index.get_level_values(1)== "disease" 
mask_quest_disease = variablesDict.index.get_level_values(1)== "\\questionnaire\\disease\\"
# line needed bc dictionaries doesn't return the same column type for categorical and numerical variables
age_disease_variables = variablesDict.loc[mask_disease | mask_quest_disease]
age_disease_variables
# Out:
#                                                                                                                     simplified_name  \
# level_0       level_1 level_2                                            level_3
# questionnaire disease NaN                                                NaN                                                disease
#                       Any CAD (self report)                              NaN                                  Any CAD (self report)
#                       Any Diabetes (FBG >= 126 mg per dL or self-report) NaN      Any Diabetes (FBG >= 126 mg per dL or self-rep...
#                       Any Hypertension? (BP >= 139 per 90 or self rep... NaN      Any Hypertension? (BP >= 139 per 90 or self re...
#                       Any cancer or malignancy?                          NaN                              Any cancer or malignancy?
#                       Any family with heart attack or angina?            NaN                Any family with heart attack or angina?
#                       Current asthma?                                    NaN                                        Current asthma?
#                       Ever arthritis?                                    NaN                                        Ever arthritis?
#                       Ever asthma?                                       NaN                                           Ever asthma?
#                       Ever osteo arthritis?                              NaN                                  Ever osteo arthritis?
#                       Ever rheumatoid arthritis?                         NaN                             Ever rheumatoid arthritis?
#                       any_cad                                            NaN                                                any_cad
#                       any_chronic_disease                                NaN                                    any_chronic_disease
#                       bladder_cancer_self_report                         NaN                             bladder_cancer_self_report
#                       blood_cancer_self_report                           NaN                               blood_cancer_self_report
#                       bone_cancer_self_report                            NaN                                bone_cancer_self_report
#                       brain_cancer_self_report                           NaN                               brain_cancer_self_report
#                       breast_cancer_self_report                          NaN                              breast_cancer_self_report
#                       cervix_cacner_self_report                          NaN                              cervix_cacner_self_report
#                       chronic_disease_count                              NaN                                  chronic_disease_count
#                       colon_cancer_self_report                           NaN                               colon_cancer_self_report
#                       esophagus_cancer_self_report                       NaN                           esophagus_cancer_self_report
#                       gallbladder_cancer_self_report                     NaN                         gallbladder_cancer_self_report
#                       kidney_cancer_self_report                          NaN                              kidney_cancer_self_report
#                       larynx_cancer_self_report                          NaN                              larynx_cancer_self_report
#                       leukemia_self_report                               NaN                                   leukemia_self_report
#                       liver_cancer_self_report                           NaN                               liver_cancer_self_report
#                       lung_cancer_self_report                            NaN                                lung_cancer_self_report
#                       lymphoma_self_report                               NaN                                   lymphoma_self_report
#                       melanoma_self_report                               NaN                                   melanoma_self_report
#                       mouth_cancer_self_report                           NaN                               mouth_cancer_self_report
#                       nervous_cancer_self_report                         NaN                             nervous_cancer_self_report
#                       other_cancer_self_report                           NaN                               other_cancer_self_report
#                       other_skin_cancer_self_report                      NaN                          other_skin_cancer_self_report
#                       ovarian_cancer_self_report                         NaN                             ovarian_cancer_self_report
#                       pancreatic_cancer_self_report                      NaN                          pancreatic_cancer_self_report
#                       prostate_cancer_self_report                        NaN                            prostate_cancer_self_report
#                       rectum_cancer_self_report                          NaN                              rectum_cancer_self_report
#                       skin_cancer_self_report                            NaN                                skin_cancer_self_report
#                       soft_cancer_self_report                            NaN                                soft_cancer_self_report
#                       stomach_cancer_self_report                         NaN                             stomach_cancer_self_report
#                       testis_cancer_self_report                          NaN                              testis_cancer_self_report
#                       thyroid_cancer_self_report                         NaN                             thyroid_cancer_self_report
#                       uterine_cancer_self_report                         NaN                             uterine_cancer_self_report
#
#                                                                                                                                name  \
# level_0       level_1 level_2                                            level_3
# questionnaire disease NaN                                                NaN                                \questionnaire\disease\
#                       Any CAD (self report)                              NaN          \questionnaire\disease\Any CAD (self report)\
#                       Any Diabetes (FBG >= 126 mg per dL or self-report) NaN      \questionnaire\disease\Any Diabetes (FBG >= 12...
#                       Any Hypertension? (BP >= 139 per 90 or self rep... NaN      \questionnaire\disease\Any Hypertension? (BP >...
#                       Any cancer or malignancy?                          NaN      \questionnaire\disease\Any cancer or malignancy?\
#                       Any family with heart attack or angina?            NaN      \questionnaire\disease\Any family with heart a...
#                       Current asthma?                                    NaN                \questionnaire\disease\Current asthma?\
#                       Ever arthritis?                                    NaN                \questionnaire\disease\Ever arthritis?\
#                       Ever asthma?                                       NaN                   \questionnaire\disease\Ever asthma?\
#                       Ever osteo arthritis?                              NaN          \questionnaire\disease\Ever osteo arthritis?\
#                       Ever rheumatoid arthritis?                         NaN      \questionnaire\disease\Ever rheumatoid arthrit...
#                       any_cad                                            NaN                        \questionnaire\disease\any_cad\
#                       any_chronic_disease                                NaN            \questionnaire\disease\any_chronic_disease\
#                       bladder_cancer_self_report                         NaN      \questionnaire\disease\bladder_cancer_self_rep...
#                       blood_cancer_self_report                           NaN       \questionnaire\disease\blood_cancer_self_report\
#                       bone_cancer_self_report                            NaN        \questionnaire\disease\bone_cancer_self_report\
#                       brain_cancer_self_report                           NaN       \questionnaire\disease\brain_cancer_self_report\
#                       breast_cancer_self_report                          NaN      \questionnaire\disease\breast_cancer_self_report\
#                       cervix_cacner_self_report                          NaN      \questionnaire\disease\cervix_cacner_self_report\
#                       chronic_disease_count                              NaN          \questionnaire\disease\chronic_disease_count\
#                       colon_cancer_self_report                           NaN       \questionnaire\disease\colon_cancer_self_report\
#                       esophagus_cancer_self_report                       NaN      \questionnaire\disease\esophagus_cancer_self_r...
#                       gallbladder_cancer_self_report                     NaN      \questionnaire\disease\gallbladder_cancer_self...
#                       kidney_cancer_self_report                          NaN      \questionnaire\disease\kidney_cancer_self_report\
#                       larynx_cancer_self_report                          NaN      \questionnaire\disease\larynx_cancer_self_report\
#                       leukemia_self_report                               NaN           \questionnaire\disease\leukemia_self_report\
#                       liver_cancer_self_report                           NaN       \questionnaire\disease\liver_cancer_self_report\
#                       lung_cancer_self_report                            NaN        \questionnaire\disease\lung_cancer_self_report\
#                       lymphoma_self_report                               NaN           \questionnaire\disease\lymphoma_self_report\
#                       melanoma_self_report                               NaN           \questionnaire\disease\melanoma_self_report\
#                       mouth_cancer_self_report                           NaN       \questionnaire\disease\mouth_cancer_self_report\
#                       nervous_cancer_self_report                         NaN      \questionnaire\disease\nervous_cancer_self_rep...
#                       other_cancer_self_report                           NaN       \questionnaire\disease\other_cancer_self_report\
#                       other_skin_cancer_self_report                      NaN      \questionnaire\disease\other_skin_cancer_self_...
#                       ovarian_cancer_self_report                         NaN      \questionnaire\disease\ovarian_cancer_self_rep...
#                       pancreatic_cancer_self_report                      NaN      \questionnaire\disease\pancreatic_cancer_self_...
#                       prostate_cancer_self_report                        NaN      \questionnaire\disease\prostate_cancer_self_re...
#                       rectum_cancer_self_report                          NaN      \questionnaire\disease\rectum_cancer_self_report\
#                       skin_cancer_self_report                            NaN        \questionnaire\disease\skin_cancer_self_report\
#                       soft_cancer_self_report                            NaN        \questionnaire\disease\soft_cancer_self_report\
#                       stomach_cancer_self_report                         NaN      \questionnaire\disease\stomach_cancer_self_rep...
#                       testis_cancer_self_report                          NaN      \questionnaire\disease\testis_cancer_self_report\
#                       thyroid_cancer_self_report                         NaN      \questionnaire\disease\thyroid_cancer_self_rep...
#                       uterine_cancer_self_report                         NaN      \questionnaire\disease\uterine_cancer_self_rep...
#
#                                                                                   observationCount  \
# level_0       level_1 level_2                                            level_3
# questionnaire disease NaN                                                NaN                  1195
#                       Any CAD (self report)                              NaN                  4859
#                       Any Diabetes (FBG >= 126 mg per dL or self-report) NaN                  9451
#                       Any Hypertension? (BP >= 139 per 90 or self rep... NaN                  5997
#                       Any cancer or malignancy?                          NaN                  4886
#                       Any family with heart attack or angina?            NaN                  4765
#                       Current asthma?                                    NaN                  8971
#                       Ever arthritis?                                    NaN                  4886
#                       Ever asthma?                                       NaN                  9499
#                       Ever osteo arthritis?                              NaN                  4015
#                       Ever rheumatoid arthritis?                         NaN                  3911
#                       any_cad                                            NaN                  4891
#                       any_chronic_disease                                NaN                  9999
#                       bladder_cancer_self_report                         NaN                  4483
#                       blood_cancer_self_report                           NaN                  4476
#                       bone_cancer_self_report                            NaN                  4483
#                       brain_cancer_self_report                           NaN                  4477
#                       breast_cancer_self_report                          NaN                  4546
#                       cervix_cacner_self_report                          NaN                  4504
#                       chronic_disease_count                              NaN                  9999
#                       colon_cancer_self_report                           NaN                  4508
#                       esophagus_cancer_self_report                       NaN                  4477
#                       gallbladder_cancer_self_report                     NaN                  4476
#                       kidney_cancer_self_report                          NaN                  4484
#                       larynx_cancer_self_report                          NaN                  4481
#                       leukemia_self_report                               NaN                  4481
#                       liver_cancer_self_report                           NaN                  4478
#                       lung_cancer_self_report                            NaN                  4486
#                       lymphoma_self_report                               NaN                  4485
#                       melanoma_self_report                               NaN                  4496
#                       mouth_cancer_self_report                           NaN                  4477
#                       nervous_cancer_self_report                         NaN                  4476
#                       other_cancer_self_report                           NaN                  4494
#                       other_skin_cancer_self_report                      NaN                  4514
#                       ovarian_cancer_self_report                         NaN                  4491
#                       pancreatic_cancer_self_report                      NaN                  4476
#                       prostate_cancer_self_report                        NaN                  4546
#                       rectum_cancer_self_report                          NaN                  4481
#                       skin_cancer_self_report                            NaN                  4542
#                       soft_cancer_self_report                            NaN                  4478
#                       stomach_cancer_self_report                         NaN                  4480
#                       testis_cancer_self_report                          NaN                  4479
#                       thyroid_cancer_self_report                         NaN                  4486
#                       uterine_cancer_self_report                         NaN                  4496
#
#                                                                                   categorical  \
# level_0       level_1 level_2                                            level_3
# questionnaire disease NaN                                                NaN            False
#                       Any CAD (self report)                              NaN             True
#                       Any Diabetes (FBG >= 126 mg per dL or self-report) NaN             True
#                       Any Hypertension? (BP >= 139 per 90 or self rep... NaN             True
#                       Any cancer or malignancy?                          NaN             True
#                       Any family with heart attack or angina?            NaN             True
#                       Current asthma?                                    NaN             True
#                       Ever arthritis?                                    NaN             True
#                       Ever asthma?                                       NaN             True
#                       Ever osteo arthritis?                              NaN             True
#                       Ever rheumatoid arthritis?                         NaN             True
#                       any_cad                                            NaN             True
#                       any_chronic_disease                                NaN             True
#                       bladder_cancer_self_report                         NaN             True
#                       blood_cancer_self_report                           NaN             True
#                       bone_cancer_self_report                            NaN             True
#                       brain_cancer_self_report                           NaN             True
#                       breast_cancer_self_report                          NaN             True
#                       cervix_cacner_self_report                          NaN             True
#                       chronic_disease_count                              NaN            False
#                       colon_cancer_self_report                           NaN             True
#                       esophagus_cancer_self_report                       NaN             True
#                       gallbladder_cancer_self_report                     NaN            False
#                       kidney_cancer_self_report                          NaN             True
#                       larynx_cancer_self_report                          NaN             True
#                       leukemia_self_report                               NaN             True
#                       liver_cancer_self_report                           NaN             True
#                       lung_cancer_self_report                            NaN             True
#                       lymphoma_self_report                               NaN             True
#                       melanoma_self_report                               NaN             True
#                       mouth_cancer_self_report                           NaN             True
#                       nervous_cancer_self_report                         NaN            False
#                       other_cancer_self_report                           NaN             True
#                       other_skin_cancer_self_report                      NaN             True
#                       ovarian_cancer_self_report                         NaN             True
#                       pancreatic_cancer_self_report                      NaN             True
#                       prostate_cancer_self_report                        NaN             True
#                       rectum_cancer_self_report                          NaN             True
#                       skin_cancer_self_report                            NaN             True
#                       soft_cancer_self_report                            NaN             True
#                       stomach_cancer_self_report                         NaN             True
#                       testis_cancer_self_report                          NaN             True
#                       thyroid_cancer_self_report                         NaN             True
#                       uterine_cancer_self_report                         NaN             True
#
#                                                                                  categoryValues  \
# level_0       level_1 level_2                                            level_3
# questionnaire disease NaN                                                NaN               None
#                       Any CAD (self report)                              NaN          [No, Yes]
#                       Any Diabetes (FBG >= 126 mg per dL or self-report) NaN          [No, Yes]
#                       Any Hypertension? (BP >= 139 per 90 or self rep... NaN          [No, Yes]
#                       Any cancer or malignancy?                          NaN          [No, Yes]
#                       Any family with heart attack or angina?            NaN          [No, Yes]
#                       Current asthma?                                    NaN          [No, Yes]
#                       Ever arthritis?                                    NaN          [No, Yes]
#                       Ever asthma?                                       NaN          [No, Yes]
#                       Ever osteo arthritis?                              NaN          [No, Yes]
#                       Ever rheumatoid arthritis?                         NaN          [No, Yes]
#                       any_cad                                            NaN          [No, Yes]
#                       any_chronic_disease                                NaN          [No, Yes]
#                       bladder_cancer_self_report                         NaN          [No, Yes]
#                       blood_cancer_self_report                           NaN               [No]
#                       bone_cancer_self_report                            NaN          [No, Yes]
#                       brain_cancer_self_report                           NaN          [No, Yes]
#                       breast_cancer_self_report                          NaN          [No, Yes]
#                       cervix_cacner_self_report                          NaN          [No, Yes]
#                       chronic_disease_count                              NaN               None
#                       colon_cancer_self_report                           NaN          [No, Yes]
#                       esophagus_cancer_self_report                       NaN          [No, Yes]
#                       gallbladder_cancer_self_report                     NaN               None
#                       kidney_cancer_self_report                          NaN          [No, Yes]
#                       larynx_cancer_self_report                          NaN          [No, Yes]
#                       leukemia_self_report                               NaN          [No, Yes]
#                       liver_cancer_self_report                           NaN          [No, Yes]
#                       lung_cancer_self_report                            NaN          [No, Yes]
#                       lymphoma_self_report                               NaN          [No, Yes]
#                       melanoma_self_report                               NaN          [No, Yes]
#                       mouth_cancer_self_report                           NaN          [No, Yes]
#                       nervous_cancer_self_report                         NaN               None
#                       other_cancer_self_report                           NaN          [No, Yes]
#                       other_skin_cancer_self_report                      NaN          [No, Yes]
#                       ovarian_cancer_self_report                         NaN          [No, Yes]
#                       pancreatic_cancer_self_report                      NaN               [No]
#                       prostate_cancer_self_report                        NaN          [No, Yes]
#                       rectum_cancer_self_report                          NaN          [No, Yes]
#                       skin_cancer_self_report                            NaN          [No, Yes]
#                       soft_cancer_self_report                            NaN          [No, Yes]
#                       stomach_cancer_self_report                         NaN          [No, Yes]
#                       testis_cancer_self_report                          NaN          [No, Yes]
#                       thyroid_cancer_self_report                         NaN          [No, Yes]
#                       uterine_cancer_self_report                         NaN          [No, Yes]
#
#                                                                                   nb_modalities  \
# level_0       level_1 level_2                                            level_3
# questionnaire disease NaN                                                NaN                NaN
#                       Any CAD (self report)                              NaN                2.0
#                       Any Diabetes (FBG >= 126 mg per dL or self-report) NaN                2.0
#                       Any Hypertension? (BP >= 139 per 90 or self rep... NaN                2.0
#                       Any cancer or malignancy?                          NaN                2.0
#                       Any family with heart attack or angina?            NaN                2.0
#                       Current asthma?                                    NaN                2.0
#                       Ever arthritis?                                    NaN                2.0
#                       Ever asthma?                                       NaN                2.0
#                       Ever osteo arthritis?                              NaN                2.0
#                       Ever rheumatoid arthritis?                         NaN                2.0
#                       any_cad                                            NaN                2.0
#                       any_chronic_disease                                NaN                2.0
#                       bladder_cancer_self_report                         NaN                2.0
#                       blood_cancer_self_report                           NaN                1.0
#                       bone_cancer_self_report                            NaN                2.0
#                       brain_cancer_self_report                           NaN                2.0
#                       breast_cancer_self_report                          NaN                2.0
#                       cervix_cacner_self_report                          NaN                2.0
#                       chronic_disease_count                              NaN                NaN
#                       colon_cancer_self_report                           NaN                2.0
#                       esophagus_cancer_self_report                       NaN                2.0
#                       gallbladder_cancer_self_report                     NaN                NaN
#                       kidney_cancer_self_report                          NaN                2.0
#                       larynx_cancer_self_report                          NaN                2.0
#                       leukemia_self_report                               NaN                2.0
#                       liver_cancer_self_report                           NaN                2.0
#                       lung_cancer_self_report                            NaN                2.0
#                       lymphoma_self_report                               NaN                2.0
#                       melanoma_self_report                               NaN                2.0
#                       mouth_cancer_self_report                           NaN                2.0
#                       nervous_cancer_self_report                         NaN                NaN
#                       other_cancer_self_report                           NaN                2.0
#                       other_skin_cancer_self_report                      NaN                2.0
#                       ovarian_cancer_self_report                         NaN                2.0
#                       pancreatic_cancer_self_report                      NaN                1.0
#                       prostate_cancer_self_report                        NaN                2.0
#                       rectum_cancer_self_report                          NaN                2.0
#                       skin_cancer_self_report                            NaN                2.0
#                       soft_cancer_self_report                            NaN                2.0
#                       stomach_cancer_self_report                         NaN                2.0
#                       testis_cancer_self_report                          NaN                2.0
#                       thyroid_cancer_self_report                         NaN                2.0
#                       uterine_cancer_self_report                         NaN                2.0
#
#                                                                                    min  \
# level_0       level_1 level_2                                            level_3
# questionnaire disease NaN                                                NaN      12.8
#                       Any CAD (self report)                              NaN       NaN
#                       Any Diabetes (FBG >= 126 mg per dL or self-report) NaN       NaN
#                       Any Hypertension? (BP >= 139 per 90 or self rep... NaN       NaN
#                       Any cancer or malignancy?                          NaN       NaN
#                       Any family with heart attack or angina?            NaN       NaN
#                       Current asthma?                                    NaN       NaN
#                       Ever arthritis?                                    NaN       NaN
#                       Ever asthma?                                       NaN       NaN
#                       Ever osteo arthritis?                              NaN       NaN
#                       Ever rheumatoid arthritis?                         NaN       NaN
#                       any_cad                                            NaN       NaN
#                       any_chronic_disease                                NaN       NaN
#                       bladder_cancer_self_report                         NaN       NaN
#                       blood_cancer_self_report                           NaN       NaN
#                       bone_cancer_self_report                            NaN       NaN
#                       brain_cancer_self_report                           NaN       NaN
#                       breast_cancer_self_report                          NaN       NaN
#                       cervix_cacner_self_report                          NaN       NaN
#                       chronic_disease_count                              NaN       0.0
#                       colon_cancer_self_report                           NaN       NaN
#                       esophagus_cancer_self_report                       NaN       NaN
#                       gallbladder_cancer_self_report                     NaN       0.0
#                       kidney_cancer_self_report                          NaN       NaN
#                       larynx_cancer_self_report                          NaN       NaN
#                       leukemia_self_report                               NaN       NaN
#                       liver_cancer_self_report                           NaN       NaN
#                       lung_cancer_self_report                            NaN       NaN
#                       lymphoma_self_report                               NaN       NaN
#                       melanoma_self_report                               NaN       NaN
#                       mouth_cancer_self_report                           NaN       NaN
#                       nervous_cancer_self_report                         NaN       0.0
#                       other_cancer_self_report                           NaN       NaN
#                       other_skin_cancer_self_report                      NaN       NaN
#                       ovarian_cancer_self_report                         NaN       NaN
#                       pancreatic_cancer_self_report                      NaN       NaN
#                       prostate_cancer_self_report                        NaN       NaN
#                       rectum_cancer_self_report                          NaN       NaN
#                       skin_cancer_self_report                            NaN       NaN
#                       soft_cancer_self_report                            NaN       NaN
#                       stomach_cancer_self_report                         NaN       NaN
#                       testis_cancer_self_report                          NaN       NaN
#                       thyroid_cancer_self_report                         NaN       NaN
#                       uterine_cancer_self_report                         NaN       NaN
#
#                                                                                             max  \
# level_0       level_1 level_2                                            level_3
# questionnaire disease NaN                                                NaN       5.279000e+02
#                       Any CAD (self report)                              NaN                NaN
#                       Any Diabetes (FBG >= 126 mg per dL or self-report) NaN                NaN
#                       Any Hypertension? (BP >= 139 per 90 or self rep... NaN                NaN
#                       Any cancer or malignancy?                          NaN                NaN
#                       Any family with heart attack or angina?            NaN                NaN
#                       Current asthma?                                    NaN                NaN
#                       Ever arthritis?                                    NaN                NaN
#                       Ever asthma?                                       NaN                NaN
#                       Ever osteo arthritis?                              NaN                NaN
#                       Ever rheumatoid arthritis?                         NaN                NaN
#                       any_cad                                            NaN                NaN
#                       any_chronic_disease                                NaN                NaN
#                       bladder_cancer_self_report                         NaN                NaN
#                       blood_cancer_self_report                           NaN                NaN
#                       bone_cancer_self_report                            NaN                NaN
#                       brain_cancer_self_report                           NaN                NaN
#                       breast_cancer_self_report                          NaN                NaN
#                       cervix_cacner_self_report                          NaN                NaN
#                       chronic_disease_count                              NaN       4.000000e+00
#                       colon_cancer_self_report                           NaN                NaN
#                       esophagus_cancer_self_report                       NaN                NaN
#                       gallbladder_cancer_self_report                     NaN      4.940656e-324
#                       kidney_cancer_self_report                          NaN                NaN
#                       larynx_cancer_self_report                          NaN                NaN
#                       leukemia_self_report                               NaN                NaN
#                       liver_cancer_self_report                           NaN                NaN
#                       lung_cancer_self_report                            NaN                NaN
#                       lymphoma_self_report                               NaN                NaN
#                       melanoma_self_report                               NaN                NaN
#                       mouth_cancer_self_report                           NaN                NaN
#                       nervous_cancer_self_report                         NaN      4.940656e-324
#                       other_cancer_self_report                           NaN                NaN
#                       other_skin_cancer_self_report                      NaN                NaN
#                       ovarian_cancer_self_report                         NaN                NaN
#                       pancreatic_cancer_self_report                      NaN                NaN
#                       prostate_cancer_self_report                        NaN                NaN
#                       rectum_cancer_self_report                          NaN                NaN
#                       skin_cancer_self_report                            NaN                NaN
#                       soft_cancer_self_report                            NaN                NaN
#                       stomach_cancer_self_report                         NaN                NaN
#                       testis_cancer_self_report                          NaN                NaN
#                       thyroid_cancer_self_report                         NaN                NaN
#                       uterine_cancer_self_report                         NaN                NaN
#
#                                                                                  HpdsDataType
# level_0       level_1 level_2                                            level_3
# questionnaire disease NaN                                                NaN       phenotypes
#                       Any CAD (self report)                              NaN       phenotypes
#                       Any Diabetes (FBG >= 126 mg per dL or self-report) NaN       phenotypes
#                       Any Hypertension? (BP >= 139 per 90 or self rep... NaN       phenotypes
#                       Any cancer or malignancy?                          NaN       phenotypes
#                       Any family with heart attack or angina?            NaN       phenotypes
#                       Current asthma?                                    NaN       phenotypes
#                       Ever arthritis?                                    NaN       phenotypes
#                       Ever asthma?                                       NaN       phenotypes
#                       Ever osteo arthritis?                              NaN       phenotypes
#                       Ever rheumatoid arthritis?                         NaN       phenotypes
#                       any_cad                                            NaN       phenotypes
#                       any_chronic_disease                                NaN       phenotypes
#                       bladder_cancer_self_report                         NaN       phenotypes
#                       blood_cancer_self_report                           NaN       phenotypes
#                       bone_cancer_self_report                            NaN       phenotypes
#                       brain_cancer_self_report                           NaN       phenotypes
#                       breast_cancer_self_report                          NaN       phenotypes
#                       cervix_cacner_self_report                          NaN       phenotypes
#                       chronic_disease_count                              NaN       phenotypes
#                       colon_cancer_self_report                           NaN       phenotypes
#                       esophagus_cancer_self_report                       NaN       phenotypes
#                       gallbladder_cancer_self_report                     NaN       phenotypes
#                       kidney_cancer_self_report                          NaN       phenotypes
#                       larynx_cancer_self_report                          NaN       phenotypes
#                       leukemia_self_report                               NaN       phenotypes
#                       liver_cancer_self_report                           NaN       phenotypes
#                       lung_cancer_self_report                            NaN       phenotypes
#                       lymphoma_self_report                               NaN       phenotypes
#                       melanoma_self_report                               NaN       phenotypes
#                       mouth_cancer_self_report                           NaN       phenotypes
#                       nervous_cancer_self_report                         NaN       phenotypes
#                       other_cancer_self_report                           NaN       phenotypes
#                       other_skin_cancer_self_report                      NaN       phenotypes
#                       ovarian_cancer_self_report                         NaN       phenotypes
#                       pancreatic_cancer_self_report                      NaN       phenotypes
#                       prostate_cancer_self_report                        NaN       phenotypes
#                       rectum_cancer_self_report                          NaN       phenotypes
#                       skin_cancer_self_report                            NaN       phenotypes
#                       soft_cancer_self_report                            NaN       phenotypes
#                       stomach_cancer_self_report                         NaN       phenotypes
#                       testis_cancer_self_report                          NaN       phenotypes
#                       thyroid_cancer_self_report                         NaN       phenotypes
#                       uterine_cancer_self_report                         NaN       phenotypes

# %% [markdown]
# **The `.DataFrame()` method enables to get the result of the dictionary search in a pandas DataFrame format. This way, it allows to:**
#
#
# * Use the various information exposed in the dictionary (patient count, variable type ...) as criteria for variable selection.
# * Use the row names of the DataFrame to get the actual variables names, to be used in the query, as shown below.
#
# Variable names, aren't very pratical to use right away, for two reasons:
# 1. Very long
# 2. Presence of backslashes that prevent from copy-pasting.
#
# However, retrieving the dictionary search result in the form of a dataframe can help to deal with this, as below:

# %%
fullVariableDict = resource.dictionary().find().DataFrame()
variablesDict = get_multiIndex_variablesDict(fullVariableDict)
mask_disease = variablesDict.index.get_level_values(1) == "disease"
mask_age = variablesDict.index.get_level_values(1) == "AGE"
mask_current_asthma = variablesDict.index.get_level_values(2) == "Current asthma?"
mask_ever_asthma = variablesDict.index.get_level_values(2) == "Ever asthma?"
mask_lung_cancer = variablesDict.index.get_level_values(2) == "lung_cancer_self_report"
lung_disease_variables = variablesDict.loc[mask_current_asthma | mask_ever_asthma | mask_lung_cancer | mask_age,:]
lung_disease_variables
# Out:
#                                                                simplified_name  \
# level_0       level_1 level_2                 level_3
# demographics  AGE     NaN                     NaN                          AGE
# questionnaire disease Current asthma?         NaN              Current asthma?
#                       Ever asthma?            NaN                 Ever asthma?
#                       lung_cancer_self_report NaN      lung_cancer_self_report
#
#                                                                                                   name  \
# level_0       level_1 level_2                 level_3
# demographics  AGE     NaN                     NaN                                   \demographics\AGE\
# questionnaire disease Current asthma?         NaN              \questionnaire\disease\Current asthma?\
#                       Ever asthma?            NaN                 \questionnaire\disease\Ever asthma?\
#                       lung_cancer_self_report NaN      \questionnaire\disease\lung_cancer_self_report\
#
#                                                        observationCount  \
# level_0       level_1 level_2                 level_3
# demographics  AGE     NaN                     NaN                  9999
# questionnaire disease Current asthma?         NaN                  8971
#                       Ever asthma?            NaN                  9499
#                       lung_cancer_self_report NaN                  4486
#
#                                                        categorical  \
# level_0       level_1 level_2                 level_3
# demographics  AGE     NaN                     NaN            False
# questionnaire disease Current asthma?         NaN             True
#                       Ever asthma?            NaN             True
#                       lung_cancer_self_report NaN             True
#
#                                                       categoryValues  \
# level_0       level_1 level_2                 level_3
# demographics  AGE     NaN                     NaN               None
# questionnaire disease Current asthma?         NaN          [No, Yes]
#                       Ever asthma?            NaN          [No, Yes]
#                       lung_cancer_self_report NaN          [No, Yes]
#
#                                                        nb_modalities  min  \
# level_0       level_1 level_2                 level_3
# demographics  AGE     NaN                     NaN                NaN  0.0
# questionnaire disease Current asthma?         NaN                2.0  NaN
#                       Ever asthma?            NaN                2.0  NaN
#                       lung_cancer_self_report NaN                2.0  NaN
#
#                                                         max HpdsDataType
# level_0       level_1 level_2                 level_3
# demographics  AGE     NaN                     NaN      85.0   phenotypes
# questionnaire disease Current asthma?         NaN       NaN   phenotypes
#                       Ever asthma?            NaN       NaN   phenotypes
#                       lung_cancer_self_report NaN       NaN   phenotypes

# %% [markdown]
# Indeed, using the `dictionary.find()` function without arguments returns all concepts in the dataset, as shown in the help documentation.

# %% [markdown]
# The dictionary currently returned by the API provides information about the variables, such as:
# - observationCount: number of entries with non-null value
# - categorical: type of the variables, True if strings, False if numerical
# - min/max: only provided for numerical variables
# - HpdsDataType: 'phenotypes' or 'genotypes'. Currently this environment only has phenotype variables loaded, other environments have genotype data as well.

# %% [markdown]
# #### Variable dictionary + pandas multiIndex

# %% [markdown]
# We can use a simple user-defined function (`get_multiIndex_variablesDict`) to add a little more information to the variable dictionary and to simplify working with variables names. It takes advantage of pandas MultiIndex functionality [see pandas official documentation on this topic](https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html).
#
# Although not an official feature of the API, such functionality illustrates how to quickly select groups of related variables.
#
# Printing the 'multiIndexed' variable Dictionary allows to quickly see the tree-like organisation of the variable names. Moreover, original and simplified variable names are now stored respectively in the "varName" and "simplified_varName" columns (simplified variable names is simply the last component of the variable name, that is usually the most informative to know what each variable is about).

# %%
# Out:
#                                                                simplified_name  \
# level_0       level_1 level_2                 level_3
# questionnaire disease Current asthma?         NaN              Current asthma?
#                       Ever asthma?            NaN                 Ever asthma?
#                       lung_cancer_self_report NaN      lung_cancer_self_report
#
#                                                                                                   name  \
# level_0       level_1 level_2                 level_3
# questionnaire disease Current asthma?         NaN              \questionnaire\disease\Current asthma?\
#                       Ever asthma?            NaN                 \questionnaire\disease\Ever asthma?\
#                       lung_cancer_self_report NaN      \questionnaire\disease\lung_cancer_self_report\
#
#                                                        observationCount  \
# level_0       level_1 level_2                 level_3
# questionnaire disease Current asthma?         NaN                  8971
#                       Ever asthma?            NaN                  9499
#                       lung_cancer_self_report NaN                  4486
#
#                                                        categorical  \
# level_0       level_1 level_2                 level_3
# questionnaire disease Current asthma?         NaN             True
#                       Ever asthma?            NaN             True
#                       lung_cancer_self_report NaN             True
#
#                                                       categoryValues  \
# level_0       level_1 level_2                 level_3
# questionnaire disease Current asthma?         NaN          [No, Yes]
#                       Ever asthma?            NaN          [No, Yes]
#                       lung_cancer_self_report NaN          [No, Yes]
#
#                                                        nb_modalities  min  \
# level_0       level_1 level_2                 level_3
# questionnaire disease Current asthma?         NaN                2.0  NaN
#                       Ever asthma?            NaN                2.0  NaN
#                       lung_cancer_self_report NaN                2.0  NaN
#
#                                                        max HpdsDataType
# level_0       level_1 level_2                 level_3
# questionnaire disease Current asthma?         NaN      NaN   phenotypes
#                       Ever asthma?            NaN      NaN   phenotypes
#                       lung_cancer_self_report NaN      NaN   phenotypes

# %% [markdown]
# Below is a simple example to illustrate the simplicity of use a multiIndex dictionary. Let's say we are interested in every variables pertaining to the "Medical history" and "Medication history" subcategories.

# %%
mask_medication = variablesDict.index.get_level_values(2) == "Medication History"
mask_medical = variablesDict.index.get_level_values(2) == "Medical History"
medication_history_variables = variablesDict.loc[mask_medical | mask_medication,:]
medication_history_variables
age_concept_path
# Out:
# '\\questionnaire\\occupation\\occupation_midmanage\\'

# %%
questdisdf = resource.dictionary().find("\\questionnaire\\disease\\").DataFrame()
questdisdf

diseasedf = resource.dictionary().find("Disease").DataFrame()
diseasedf[diseasedf.categorical == True]
disease_concept_path = diseasedf.index[0]

bmidf = resource.dictionary().find("BMI")
bmidf.DataFrame()


diseasedf = resource.dictionary().find("Disease").DataFrame()
diseasedf[diseasedf.categorical == True]
disease_concept_path = diseasedf.index[0]
disease_concept_path
""
agedf = resource.dictionary().find("Age").DataFrame()
agedf[agedf.categorical == True]
age_concept_path = agedf.index[0]
age_concept_path


fullVariableDict = resource.dictionary().find().DataFrame()
variablesDict = get_multiIndex_variablesDict(fullVariableDict)
mask_disease = variablesDict.index.get_level_values(1) == "disease"
mask_age = variablesDict.index.get_level_values(1) == "AGE"
mask_current_asthma = variablesDict.index.get_level_values(2) == "Current asthma?"
mask_ever_asthma = variablesDict.index.get_level_values(2) == "Ever asthma?"
mask_lung_cancer = variablesDict.index.get_level_values(2) == "lung_cancer_self_report"
lung_disease_variables = variablesDict.loc[mask_current_asthma | mask_ever_asthma | mask_lung_cancer | ~mask_age,:]
lung_disease_variables
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Although pretty simple, it can be easily combined with other filters to quickly select desired group of variables.

# %% [markdown]
# ## Querying for participant counts and retrieving data

# %% [markdown]
# Beside from the dictionary, the second cornerstone of the API is the `query` object. It is the entering point to perform counts of participants meeting certain filters and extract data from the resource.

# %% [markdown]
# First, we need to create a query object.

# %%
my_query = resource.query()
my_query

# %% [markdown]
# The query object has several methods that enable to build a query.

# %% [markdown]
# - The `query.select.add()` method accepts variable names as string or list of strings as argument, and will allow the query to return all variables included in the list, without any record (ie subjects/rows) subsetting.

# %% [markdown]
# - The `query.require.add()` method accepts variable names as string or list of strings as argument, and will allow the query to return all the variables passed, and only records that do not contain any null values for those variables.

# %% [markdown]
# - The `query.anyof.add()` method accepts variable names as string or list of strings as argument, and will allow the query to return all variables included in the list, and only records that do contain at least one non-null value for those variables.

# %% [markdown]
# - The `query.filter.add()` method accepts a variable name as argument, plus additional values to filter on that given variable. The query will return this variable and only the records that do match this filter criteria.

# %% [markdown]
# All those 4 methods can be combined when building a query. The record eventually returned by the query have to meet all the different specified filters.

# %% [markdown]
# #### Building the query

# %% [markdown]
# Let's say we want to see how many participants in the dataset are males between the age of 35 and 50 and who quit smoking before age 30.
#
# First we will need to find the variables related to our problem. So we will search for a categorical variable that represents gender, a continuous variable representing the current age, and a variable that represents when the participant quit smoking.
#
# Because gender can be labeled differently in different studies (sex,gender), it is usually more productive to search for the more consistently present value "male". We also know we want a categorical concept so we can filter the results that way.

# %%
# Out:
# ERROR: cannot add, key does not exist in resource ->  categorical
# ERROR: cannot add, key does not exist in resource ->  categoryValues
# ERROR: cannot add, key does not exist in resource ->  patientCount
# ERROR: cannot add, key does not exist in resource ->  observationCount
# ERROR: cannot add, key does not exist in resource ->  HpdsDataType
# ERROR: cannot add, key does not exist in resource ->  min
# ERROR: cannot add, key does not exist in resource ->  max
# ERROR: cannot add, key does not exist in resource ->  min
# ERROR: cannot add, key does not exist in resource ->  categorical
# ERROR: cannot add, key does not exist in resource ->  patientCount
# ERROR: cannot add, key does not exist in resource ->  observationCount
# ERROR: cannot add, key does not exist in resource ->  max
# ERROR: cannot add, key does not exist in resource ->  HpdsDataType
#       Patient ID
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ...          ...
# 9994        9995
# 9995        9996
# 9996        9997
# 9997        9998
# 9998        9999
#
# [9999 rows x 1 columns]

# %%
q2criteria.extend(d.find("BP").keys())
q2criteria.extend(d.find("\\Body Mass Index").keys())

multiIndexdic = get_multiIndex_variablesDict(harmonized_dic)
multiIndexdic_sub = multiIndexdic.loc[~ multiIndexdic["simplified_name"].str.contains("(^[Aa]ge)|(SUBJECT_ID)", regex=True),:]

mask_demo = multiIndexdic_sub.index.get_level_values(1) == '01 - Demographics'
variablesDict = multiIndexdic_sub.loc[mask_demo,:]

selected_vars = variablesDict.loc[:, "name"].tolist()
#selected_vars.append("\\_Consents\\Short Study Accession with Consent Code\\")

pprint(selected_vars[:5])

Retrieving the data:

query = resource.query()
query.select().add(selected_vars)
facts = query.getResultsDataFrame(low_memory=False)

facts = facts.set_index("Patient ID")\
    .dropna(axis=0, how="all")\
    .drop(["\\_Consents\\Short Study Accession with Consent Code\\"], axis=1)
#facts.columns = variablesDict.set_index("name").loc[selected_vars, "simplified_name"]

# %%
disease_concept_path = diseasedf.index[0]
disease_concept_path
age_concept_path.count()

# map a color field for the plot to use
#sex_colors = {'male':'#5a7dd040', 'female':'#ffbabb40'}
#df_mf['\\sex_color\\'] = df_mf['\\demographics\\SEX\\'].map(sex_colors)


mask = variablesDict["simplified_name"] == "How old were you when you completely stopped smoking? [Years old]"
yo_stop_smoking_varname = variablesDict.loc[mask, "name"] 

mask_cat = variablesDict["categorical"] == True
mask_count = variablesDict["observationCount"].between(100,2000)
varnames = variablesDict.loc[mask_cat & mask_count, "name"]

my_query.filter().add(yo_stop_smoking_varname, min=20, max=70)
my_query.select().add(varnames[:50])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-812-20dbd80b8588> in <module>
#       1 disease_concept_path = diseasedf.index[0]
#       2 disease_concept_path
# ----> 3 age_concept_path.count()
#       4
#       5 # map a color field for the plot to use
#
# TypeError: count() takes at least 1 argument (0 given)

# %% [markdown]
# OK, pretty obvious we want \demographics\sex\ as our gender concept path.
#
# Moving on to the age concept paths, this can be more complicated as the term "age" shows up in lots of concepts, it is a very common string of 3 characters.

# %%
multiIndexdic = get_multiIndex_variablesDict(harmonized_dic)
multiIndexdic_sub = multiIndexdic.loc[~ multiIndexdic["simplified_name"].str.contains("(^[Aa]ge)|(SUBJECT_ID)", regex=True),:]

mask_demo = multiIndexdic_sub.index.get_level_values(1) == '01 - Demographics'
variablesDict = multiIndexdic_sub.loc[mask_demo,:]

selected_vars = variablesDict.loc[:, "name"].tolist()
#selected_vars.append("\\_Consents\\Short Study Accession with Consent Code\\")

pprint(selected_vars[:5])

Retrieving the data:

query = resource.query()
query.select().add(selected_vars)
facts = query.getResultsDataFrame(low_memory=False)

facts = facts.set_index("Patient ID")\
    .dropna(axis=0, how="all")\
    .drop(["\\_Consents\\Short Study Accession with Consent Code\\"], axis=1)
#facts.columns = variablesDict.set_index("name").loc[selected_vars, "simplified_name"]
# Out:
# <bound method NDFrame.head of                                                      min  categorical  \
# KEY
# \questionnaire\occupation\occupation_midmanage\      1.0        False
# \demographics\AGE\                                   0.0        False
# \examination\physical fitness\Stage 2 diastolic...  38.0        False
# \questionnaire\pharmaceutical\age_stopped_birth...  12.0        False
# \examination\physical fitness\Stage 2 systolic ...  73.0        False
# \questionnaire\smoking behavior\Age started usi...   7.0        False
# \examination\physical fitness\Stage 1 diastolic...  38.0        False
# \questionnaire\street drug\Age first used metha...  12.0        False
# \questionnaire\pharmaceutical\Age started estro...  44.0        False
# \examination\physical fitness\Stage 1 heart rat...  61.0        False
# \questionnaire\pharmaceutical\Age started estro...  25.0        False
# \questionnaire\smoking behavior\Age started smo...   7.0        False
# \questionnaire\smoking behavior\Age started che...   7.0        False
# \examination\physical fitness\Stage 1 systolic ...  53.0        False
# \examination\physical fitness\Stage 2 heart rat...  86.0        False
# \questionnaire\pharmaceutical\Age started proge...  16.0        False
# \questionnaire\street drug\Age first used heroin\   12.0        False
# \questionnaire\pharmaceutical\Age started estro...  20.0        False
# \questionnaire\smoking behavior\Age started cig...   7.0        False
# \questionnaire\smoking behavior\Age last smoked...   1.0        False
# \questionnaire\smoking behavior\Age started pip...  14.0        False
# \questionnaire\street drug\Age first used cocaine\  12.0        False
# \questionnaire\street drug\Age when first tried...   2.0        False
# \questionnaire\housing\house age\                    1.0        False
# \questionnaire\pharmaceutical\Age started estro...  16.0        False
# \questionnaire\pharmaceutical\age_started_birth...   9.0        False
#
#                                                     patientCount  \
# KEY
# \questionnaire\occupation\occupation_midmanage\              672
# \demographics\AGE\                                          9999
# \examination\physical fitness\Stage 2 diastolic...          1808
# \questionnaire\pharmaceutical\age_stopped_birth...          1309
# \examination\physical fitness\Stage 2 systolic ...          1808
# \questionnaire\smoking behavior\Age started usi...           103
# \examination\physical fitness\Stage 1 diastolic...          1958
# \questionnaire\street drug\Age first used metha...            53
# \questionnaire\pharmaceutical\Age started estro...             4
# \examination\physical fitness\Stage 1 heart rat...          2219
# \questionnaire\pharmaceutical\Age started estro...            49
# \questionnaire\smoking behavior\Age started smo...          2214
# \questionnaire\smoking behavior\Age started che...           115
# \examination\physical fitness\Stage 1 systolic ...          1958
# \examination\physical fitness\Stage 2 heart rat...          2030
# \questionnaire\pharmaceutical\Age started proge...           106
# \questionnaire\street drug\Age first used heroin\             12
# \questionnaire\pharmaceutical\Age started estro...           114
# \questionnaire\smoking behavior\Age started cig...           219
# \questionnaire\smoking behavior\Age last smoked...           895
# \questionnaire\smoking behavior\Age started pip...           176
# \questionnaire\street drug\Age first used cocaine\           137
# \questionnaire\street drug\Age when first tried...           395
# \questionnaire\housing\house age\                           7182
# \questionnaire\pharmaceutical\Age started estro...           346
# \questionnaire\pharmaceutical\age_started_birth...          1501
#
#                                                     observationCount    max  \
# KEY
# \questionnaire\occupation\occupation_midmanage\                  672    1.0
# \demographics\AGE\                                              9999   85.0
# \examination\physical fitness\Stage 2 diastolic...              1808  120.0
# \questionnaire\pharmaceutical\age_stopped_birth...              1309   57.0
# \examination\physical fitness\Stage 2 systolic ...              1808  268.0
# \questionnaire\smoking behavior\Age started usi...               103   70.0
# \examination\physical fitness\Stage 1 diastolic...              1958  129.0
# \questionnaire\street drug\Age first used metha...                53   40.0
# \questionnaire\pharmaceutical\Age started estro...                 4   58.0
# \examination\physical fitness\Stage 1 heart rat...              2219  176.0
# \questionnaire\pharmaceutical\Age started estro...                49   80.0
# \questionnaire\smoking behavior\Age started smo...              2214   72.0
# \questionnaire\smoking behavior\Age started che...               115   70.0
# \examination\physical fitness\Stage 1 systolic ...              1958  242.0
# \examination\physical fitness\Stage 2 heart rat...              2030  197.0
# \questionnaire\pharmaceutical\Age started proge...               106   69.0
# \questionnaire\street drug\Age first used heroin\                 12   29.0
# \questionnaire\pharmaceutical\Age started estro...               114   75.0
# \questionnaire\smoking behavior\Age started cig...               219   70.0
# \questionnaire\smoking behavior\Age last smoked...               895   84.0
# \questionnaire\smoking behavior\Age started pip...               176   70.0
# \questionnaire\street drug\Age first used cocaine\               137   59.0
# \questionnaire\street drug\Age when first tried...               395   44.0
# \questionnaire\housing\house age\                               7182   77.0
# \questionnaire\pharmaceutical\Age started estro...               346   80.0
# \questionnaire\pharmaceutical\age_started_birth...              1501   54.0
#
#                                                    HpdsDataType
# KEY
# \questionnaire\occupation\occupation_midmanage\      phenotypes
# \demographics\AGE\                                   phenotypes
# \examination\physical fitness\Stage 2 diastolic...   phenotypes
# \questionnaire\pharmaceutical\age_stopped_birth...   phenotypes
# \examination\physical fitness\Stage 2 systolic ...   phenotypes
# \questionnaire\smoking behavior\Age started usi...   phenotypes
# \examination\physical fitness\Stage 1 diastolic...   phenotypes
# \questionnaire\street drug\Age first used metha...   phenotypes
# \questionnaire\pharmaceutical\Age started estro...   phenotypes
# \examination\physical fitness\Stage 1 heart rat...   phenotypes
# \questionnaire\pharmaceutical\Age started estro...   phenotypes
# \questionnaire\smoking behavior\Age started smo...   phenotypes
# \questionnaire\smoking behavior\Age started che...   phenotypes
# \examination\physical fitness\Stage 1 systolic ...   phenotypes
# \examination\physical fitness\Stage 2 heart rat...   phenotypes
# \questionnaire\pharmaceutical\Age started proge...   phenotypes
# \questionnaire\street drug\Age first used heroin\    phenotypes
# \questionnaire\pharmaceutical\Age started estro...   phenotypes
# \questionnaire\smoking behavior\Age started cig...   phenotypes
# \questionnaire\smoking behavior\Age last smoked...   phenotypes
# \questionnaire\smoking behavior\Age started pip...   phenotypes
# \questionnaire\street drug\Age first used cocaine\   phenotypes
# \questionnaire\street drug\Age when first tried...   phenotypes
# \questionnaire\housing\house age\                    phenotypes
# \questionnaire\pharmaceutical\Age started estro...   phenotypes
# \questionnaire\pharmaceutical\age_started_birth...   phenotypes  >

# %%
plain_variablesDict = resource.dictionary().find().DataFrame()
variablesDict = get_multiIndex_variablesDict(plain_variablesDict)
mask_BP = variablesDict.index.get_level_values(2) == "BP"
mask_BMI = variablesDict.index.get_level_values(2) == "BMI"
BP_BMI_variables = variablesDict.loc[mask_BMI | ~mask_BP,:]
BP_BMI_variables.shape
# Out:
# (1159, 9)

# %%
df = dictionary.find("breathing").DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# We know the age concept we want for the current age is \demographics\AGE\ , that one is obvious. We can figure out when people quit smoking cigarettes using the \questionnaire\smoking behavior\Age last smoked cigarettes regularly\ concept.
#
# We've assigned these concept paths to variables so we can use them in our query.
#
# gender_concept_path
#
# age_concept_path
#
# quit_smoking_concept_path
#
# Great! Now we have all of the concept paths for our query. Let's add filters to our query to meet the original problem statement.
#
# We want to see how many participants in the dataset are males between the age of 35 and 50 and who quit smoking before age 30.

# %%
my_query = resource.query()
my_query.filter().add(gender_concept_path, "male")
my_query.filter().add(age_concept_path, min=35, max=50)
my_query.filter().add(quit_smoking_concept_path, min=1, max=30)

# %%
0-2 years
3-7 years
8-10 years
11-20 years
21-44 years

# %%
disdf = dictionary.find("disease").DataFrame()
#disdf[disdf.categorical == True]
disdf.shape
# Out:
# (44, 7)

# %%
qdisdf = dictionary.find("\\questionnaire\\disease").DataFrame()
#qdisdf[qdisdf.categorical == True]
qdisdf.shape
# Out:
# (44, 7)

# %%
disease_concept_path = df.index["lung_cancer"]
my_query.filter().add(gender_concept_path, "male")
my_query.filter().add(age_concept_path, min=35, max=50)
my_query.filter().add(quit_smoking_concept_path, min=1, max=30)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-89-7e1b2b5d6fd7> in <module>
# ----> 1 disease_concept_path = df.index["lung_cancer"]
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4099         if is_scalar(key):
#    4100             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4101             return getitem(key)
#    4102
#    4103         if isinstance(key, slice):
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
age_concept_path = df.index[1]

# %%
my_query = resource.query()
my_query.filter().add(disease_concept_path, "lung", "asthma")
my_query.filter().add(age_concept_path, min=0, max=2)
my_query.filter().add(age_concept_path, min=3, max=7)
my_query.filter().add(age_concept_path, min=8, max=10)
my_query.filter().add(age_concept_path, min=11, max=20)
my_query.filter().add(age_concept_path, min=21, max=44)
# Out:
# ERROR2: cannot add, key is not defined as a continuous variable ->  \questionnaire\disease\skin_cancer_self_report\
# ERROR2: cannot add, key is not defined as a continuous variable ->  \questionnaire\disease\skin_cancer_self_report\
# ERROR2: cannot add, key is not defined as a continuous variable ->  \questionnaire\disease\skin_cancer_self_report\
# ERROR2: cannot add, key is not defined as a continuous variable ->  \questionnaire\disease\skin_cancer_self_report\
# ERROR2: cannot add, key is not defined as a continuous variable ->  \questionnaire\disease\skin_cancer_self_report\

# %% [markdown]
# ## Retrieving participant counts for your query

# %% [markdown]
# The basis of many statistical operations is a count of things as they fit into different categories and mathematical operations on those counts. PIC-SURE is optimized to perform these counts for you. Using this ability to retrieve counts instead of raw data that needs to be counted has many benefits.
#
# From a sustainability perspective it is much cheaper to return a count than the raw data. For small datasets this benefit doesn't matter much, but as datasets have grown this became a significant concern. It costs $90 per terrabyte to retrieve data from the cloud on AWS. While 1TB sounds like a lot, it really isn't when you consider many users accessing the data all at once.
#
# From a usability perspective it is much faster to retrieve a count than to retrieve a CSV and process counts yourself. There is a researcher mindset of mistrust of things that are new, and this is justified, but our job is to gain that trust in PIC-SURE's ability to accurately count based on the filters applied.
#
# From a reproducibility perspective, a PIC-SURE Query expresses fully the filters and aggregate operations performed. The current aggregate operations are counts, but we do plan to extend that as things progress. This results in everything being captured fully. There is no opportunity for missed steps or unrecorded massaging of the data. It is always 100% reproducible.
#
# To retrieve a participant count for any query, just run the getCount function.

# %%
my_query.getCount()
# Out:
# 50

# %% [markdown]
# So we now know how many participants are in this age range and who smoked at some point and quit by age 30. By combining ranges we could build a histogram or other visualization of this data just from the counts, but how do we know we can trust the counts?

# %% [markdown]
# ## Retrieving the raw data

# %% [markdown]
# To get the raw data this count came from, you can run the getResultsDataFrame function. This enables a researcher to have greater confidence in the count or to identify abhorations in the data leading to an invalid count. Additional filters can then be added to the query to remove the abhorant data.

# %%
query_result = my_query.getResultsDataFrame(low_memory=False)

# %%
query_result.shape
# Out:
# (9999, 1)

# %% [markdown]
# ## PIC-SURE UI
#
# In addition to the API, the PIC-SURE UI can help to explore the data and figure out how many participants meet certain filter criteria. Explore PIC-SURE UI here https://3.236.133.248 to get a sense for what data is available.

# %% [markdown]
# ## Code Test Challenges
#
# Now that you have a basic understanding of how the API works, we can move on to the code test problems. Please provide solutions to the following problems using the API. You may export raw data to confirm your answers, but your solution cannot be derived directly from a dump of the raw data. The solution must come from COUNT queries. Feel free to validate your solution by exporting the data and comparing the results of the COUNT based solution to the results using any other method. Show all work in new cells added after each Problem.

# %% [markdown]
# # Problem 1

# %% [raw]
# Use count queries to get the number of participants in the dataset in the following age groups have reported a disease related to breathing? BONUS : Display a graph that illustrates the breakdown of participants by these brackets --> 0-2 years; 3-7 years; 8-10 years; 11-20 years;21-44 years
#
# copdgene_dic = resource.dictionary().find("blood pressure").DataFrame()
# consent_dic = resource.dictionary().find("physical fitness").DataFrame()
# bodymeasuredf

# %%
pmeasuredf = resource.dictionary().find("physical fitness")
pmeasuredf.DataFrame()
# Out:
#                                                       min  categorical  \
# KEY
# \examination\physical fitness\Recovery 1 heart ...  49.00        False
# \examination\physical fitness\Predicted VO2max ...   4.92        False
# \questionnaire\physical fitness\Physical Activi...   0.00        False
# \examination\physical fitness\Stage 1 heart rat...  61.00        False
# \examination\physical fitness\Stage 1 systolic ...  53.00        False
# \examination\physical fitness\Stage 2 heart rat...  86.00        False
# \examination\physical fitness\Recovery 2 diasto...  39.00        False
# \examination\physical fitness\Stage 2 diastolic...  38.00        False
# \examination\physical fitness\Recovery 2 systol...  83.00        False
# \examination\physical fitness\Stage 2 systolic ...  73.00        False
# \examination\physical fitness\Recovery 2 heart ...  69.00        False
# \examination\physical fitness\Recovery 1 systol...  75.00        False
# \examination\physical fitness\Recovery 1 diasto...  39.00        False
# \examination\physical fitness\Estimated VO2max ...  17.99        False
# \examination\physical fitness\Stage 1 diastolic...  38.00        False
#
#                                                     patientCount  \
# KEY
# \examination\physical fitness\Recovery 1 heart ...          2134
# \examination\physical fitness\Predicted VO2max ...          2402
# \questionnaire\physical fitness\Physical Activi...          5546
# \examination\physical fitness\Stage 1 heart rat...          2219
# \examination\physical fitness\Stage 1 systolic ...          1958
# \examination\physical fitness\Stage 2 heart rat...          2030
# \examination\physical fitness\Recovery 2 diasto...          2157
# \examination\physical fitness\Stage 2 diastolic...          1808
# \examination\physical fitness\Recovery 2 systol...          2157
# \examination\physical fitness\Stage 2 systolic ...          1808
# \examination\physical fitness\Recovery 2 heart ...          2158
# \examination\physical fitness\Recovery 1 systol...          2130
# \examination\physical fitness\Recovery 1 diasto...          2130
# \examination\physical fitness\Estimated VO2max ...          1998
# \examination\physical fitness\Stage 1 diastolic...          1958
#
#                                                     observationCount     max  \
# KEY
# \examination\physical fitness\Recovery 1 heart ...              2134  230.00
# \examination\physical fitness\Predicted VO2max ...              2402   74.68
# \questionnaire\physical fitness\Physical Activi...              5546    3.00
# \examination\physical fitness\Stage 1 heart rat...              2219  176.00
# \examination\physical fitness\Stage 1 systolic ...              1958  242.00
# \examination\physical fitness\Stage 2 heart rat...              2030  197.00
# \examination\physical fitness\Recovery 2 diasto...              2157  129.00
# \examination\physical fitness\Stage 2 diastolic...              1808  120.00
# \examination\physical fitness\Recovery 2 systol...              2157  236.00
# \examination\physical fitness\Stage 2 systolic ...              1808  268.00
# \examination\physical fitness\Recovery 2 heart ...              2158  175.00
# \examination\physical fitness\Recovery 1 systol...              2130  260.00
# \examination\physical fitness\Recovery 1 diasto...              2130  139.00
# \examination\physical fitness\Estimated VO2max ...              1998  112.40
# \examination\physical fitness\Stage 1 diastolic...              1958  129.00
#
#                                                    HpdsDataType
# KEY
# \examination\physical fitness\Recovery 1 heart ...   phenotypes
# \examination\physical fitness\Predicted VO2max ...   phenotypes
# \questionnaire\physical fitness\Physical Activi...   phenotypes
# \examination\physical fitness\Stage 1 heart rat...   phenotypes
# \examination\physical fitness\Stage 1 systolic ...   phenotypes
# \examination\physical fitness\Stage 2 heart rat...   phenotypes
# \examination\physical fitness\Recovery 2 diasto...   phenotypes
# \examination\physical fitness\Stage 2 diastolic...   phenotypes
# \examination\physical fitness\Recovery 2 systol...   phenotypes
# \examination\physical fitness\Stage 2 systolic ...   phenotypes
# \examination\physical fitness\Recovery 2 heart ...   phenotypes
# \examination\physical fitness\Recovery 1 systol...   phenotypes
# \examination\physical fitness\Recovery 1 diasto...   phenotypes
# \examination\physical fitness\Estimated VO2max ...   phenotypes
# \examination\physical fitness\Stage 1 diastolic...   phenotypes

# %%
pmeasuredf = resource.dictionary().find("Body Mass Index")
pmeasuredf.DataFrame()
# Out:
#                                                       min  categorical  \
# KEY
# \examination\body measures\Body Mass Index (kg ...  11.98        False
#
#                                                     patientCount  \
# KEY
# \examination\body measures\Body Mass Index (kg ...          8491
#
#                                                     observationCount     max  \
# KEY
# \examination\body measures\Body Mass Index (kg ...              8491  130.21
#
#                                                    HpdsDataType
# KEY
# \examination\body measures\Body Mass Index (kg ...   phenotypes

# %%
age_groups={'group_names':["infrant", "toddler","tyke","teen","adult","senior"],
           'min_age':[0,3,8,11,21,45],'max_age':[2,7,10,20,44,150]}

mask_pf= variablesDict.index.get_level_values(1) == "\\examination\\body measures\\physical fitness"
mask_bp = variablesDict.index.get_level_values(1) == "\\examination\\physical fitness\\blood pressure"
copdgene_dic = resource.dictionary().find("Body Mass Index").DataFrame()
consent_dic = resource.dictionary().find("physical fitness").DataFrame()
plain_variablesDict = resource.dictionary().find().DataFrame()
variablesDict = get_multiIndex_variablesDict(plain_variablesDict)
d = resource.dictionary()
q1criteria = []
q1query_unified = list()

my_query = resource.query()
#my_query.filter().add(gender_concept_path, "male")
my_query.filter().add(diseasedf,age_groups)
my_query.filter().add(agedf, age_groups)
q1criteria.extend(d.find("disease").keys())
q1criteria.extend(d.find("\\disease\\lung_cancer_self_report").keys())
q1criteria.extend(d.find("\\disease\\Current asthma?").keys())
q1criteria.extend(d.find("\\disease\\Ever asthma?").keys())
q1criteria.extend(d.find("AGE").keys())
my_query.require().add(q1criteria)
df_mf = query_unified.getResultsDataFrame()
df_mf

measuredf = resource.dictionary().find("body measures").DataFrame()
measuredf[measuredf.categorical == False]
body_measure_concept_path = measuredf.index[0]
body_measure_concept_path

fullVariableDict = resource.dictionary().find("body measures")
body_measure_df=fullVariableDict.DataFrame()
variablesDict = get_multiIndex_variablesDict(body_measure_df)
mask_measure = variablesDict.index.get_level_values(1) == "body measures"
mask_bmi = variablesDict.index.get_level_values(1) == "Body Mass Index"
mask_pf= variablesDict.index.get_level_values(1) == "\\examination\\body measures\\physical fitness"
mask_bp = variablesDict.index.get_level_values(1) == "\\examination\\physical fitness\\blood pressure"
heart_disease_variables = variablesDict.loc[mask_bmi | ~mask_bp ,:]
heart_disease_variables
# Out:
# <bound method NDFrame.keys of                                                     categorical  \
# KEY
# \questionnaire\disease\any_cad\                            True
# \questionnaire\disease\skin_cancer_self_report\            True
# \questionnaire\disease\stomach_cancer_self_report\         True
# \questionnaire\disease\brain_cancer_self_report\           True
# \questionnaire\disease\other_cancer_self_report\           True
# \questionnaire\disease\Any CAD (self report)\              True
# \questionnaire\disease\larynx_cancer_self_report\          True
# \questionnaire\disease\mouth_cancer_self_report\           True
# \questionnaire\disease\Any Diabetes (FBG >= 126...         True
# \questionnaire\disease\esophagus_cancer_self_re...         True
# \questionnaire\disease\other_skin_cancer_self_r...         True
# \questionnaire\disease\Ever asthma?\                       True
# \questionnaire\disease\testis_cancer_self_report\          True
# \questionnaire\disease\cervix_cacner_self_report\          True
# \questionnaire\disease\Ever rheumatoid arthritis?\         True
# \questionnaire\disease\kidney_cancer_self_report\          True
# \questionnaire\disease\lung_cancer_self_report\            True
# \questionnaire\disease\nervous_cancer_self_report\        False
# \questionnaire\disease\breast_cancer_self_report\          True
# \questionnaire\disease\                                   False
# \questionnaire\disease\Any Hypertension? (BP >=...         True
# \questionnaire\disease\bone_cancer_self_report\            True
# \questionnaire\disease\any_chronic_disease\                True
# \questionnaire\disease\bladder_cancer_self_report\         True
# \questionnaire\disease\lymphoma_self_report\               True
# \questionnaire\disease\soft_cancer_self_report\            True
# \questionnaire\disease\Any cancer or malignancy?\          True
# \questionnaire\disease\chronic_disease_count\             False
# \questionnaire\disease\leukemia_self_report\               True
# \questionnaire\disease\gallbladder_cancer_self_...        False
# \questionnaire\disease\liver_cancer_self_report\           True
# \questionnaire\disease\Ever arthritis?\                    True
# \questionnaire\disease\blood_cancer_self_report\           True
# \questionnaire\disease\ovarian_cancer_self_report\         True
# \questionnaire\disease\Any family with heart at...         True
# \questionnaire\disease\Current asthma?\                    True
# \questionnaire\disease\Ever osteo arthritis?\              True
# \questionnaire\disease\prostate_cancer_self_rep...         True
# \questionnaire\disease\melanoma_self_report\               True
# \questionnaire\disease\colon_cancer_self_report\           True
# \questionnaire\disease\thyroid_cancer_self_report\         True
# \questionnaire\disease\uterine_cancer_self_report\         True
# \questionnaire\disease\rectum_cancer_self_report\          True
# \questionnaire\disease\pancreatic_cancer_self_r...         True
#
#                                                    categoryValues  \
# KEY
# \questionnaire\disease\any_cad\                         [No, Yes]
# \questionnaire\disease\skin_cancer_self_report\         [No, Yes]
# \questionnaire\disease\stomach_cancer_self_report\      [No, Yes]
# \questionnaire\disease\brain_cancer_self_report\        [No, Yes]
# \questionnaire\disease\other_cancer_self_report\        [No, Yes]
# \questionnaire\disease\Any CAD (self report)\           [No, Yes]
# \questionnaire\disease\larynx_cancer_self_report\       [No, Yes]
# \questionnaire\disease\mouth_cancer_self_report\        [No, Yes]
# \questionnaire\disease\Any Diabetes (FBG >= 126...      [No, Yes]
# \questionnaire\disease\esophagus_cancer_self_re...      [No, Yes]
# \questionnaire\disease\other_skin_cancer_self_r...      [No, Yes]
# \questionnaire\disease\Ever asthma?\                    [No, Yes]
# \questionnaire\disease\testis_cancer_self_report\       [No, Yes]
# \questionnaire\disease\cervix_cacner_self_report\       [No, Yes]
# \questionnaire\disease\Ever rheumatoid arthritis?\      [No, Yes]
# \questionnaire\disease\kidney_cancer_self_report\       [No, Yes]
# \questionnaire\disease\lung_cancer_self_report\         [No, Yes]
# \questionnaire\disease\nervous_cancer_self_report\           None
# \questionnaire\disease\breast_cancer_self_report\       [No, Yes]
# \questionnaire\disease\                                      None
# \questionnaire\disease\Any Hypertension? (BP >=...      [No, Yes]
# \questionnaire\disease\bone_cancer_self_report\         [No, Yes]
# \questionnaire\disease\any_chronic_disease\             [No, Yes]
# \questionnaire\disease\bladder_cancer_self_report\      [No, Yes]
# \questionnaire\disease\lymphoma_self_report\            [No, Yes]
# \questionnaire\disease\soft_cancer_self_report\         [No, Yes]
# \questionnaire\disease\Any cancer or malignancy?\       [No, Yes]
# \questionnaire\disease\chronic_disease_count\                None
# \questionnaire\disease\leukemia_self_report\            [No, Yes]
# \questionnaire\disease\gallbladder_cancer_self_...           None
# \questionnaire\disease\liver_cancer_self_report\        [No, Yes]
# \questionnaire\disease\Ever arthritis?\                 [No, Yes]
# \questionnaire\disease\blood_cancer_self_report\             [No]
# \questionnaire\disease\ovarian_cancer_self_report\      [No, Yes]
# \questionnaire\disease\Any family with heart at...      [No, Yes]
# \questionnaire\disease\Current asthma?\                 [No, Yes]
# \questionnaire\disease\Ever osteo arthritis?\           [No, Yes]
# \questionnaire\disease\prostate_cancer_self_rep...      [No, Yes]
# \questionnaire\disease\melanoma_self_report\            [No, Yes]
# \questionnaire\disease\colon_cancer_self_report\        [No, Yes]
# \questionnaire\disease\thyroid_cancer_self_report\      [No, Yes]
# \questionnaire\disease\uterine_cancer_self_report\      [No, Yes]
# \questionnaire\disease\rectum_cancer_self_report\       [No, Yes]
# \questionnaire\disease\pancreatic_cancer_self_r...           [No]
#
#                                                     patientCount  \
# KEY
# \questionnaire\disease\any_cad\                             4891
# \questionnaire\disease\skin_cancer_self_report\             4542
# \questionnaire\disease\stomach_cancer_self_report\          4480
# \questionnaire\disease\brain_cancer_self_report\            4477
# \questionnaire\disease\other_cancer_self_report\            4494
# \questionnaire\disease\Any CAD (self report)\               4859
# \questionnaire\disease\larynx_cancer_self_report\           4481
# \questionnaire\disease\mouth_cancer_self_report\            4477
# \questionnaire\disease\Any Diabetes (FBG >= 126...          9451
# \questionnaire\disease\esophagus_cancer_self_re...          4477
# \questionnaire\disease\other_skin_cancer_self_r...          4514
# \questionnaire\disease\Ever asthma?\                        9499
# \questionnaire\disease\testis_cancer_self_report\           4479
# \questionnaire\disease\cervix_cacner_self_report\           4504
# \questionnaire\disease\Ever rheumatoid arthritis?\          3911
# \questionnaire\disease\kidney_cancer_self_report\           4484
# \questionnaire\disease\lung_cancer_self_report\             4486
# \questionnaire\disease\nervous_cancer_self_report\          4476
# \questionnaire\disease\breast_cancer_self_report\           4546
# \questionnaire\disease\                                     1195
# \questionnaire\disease\Any Hypertension? (BP >=...          5997
# \questionnaire\disease\bone_cancer_self_report\             4483
# \questionnaire\disease\any_chronic_disease\                 9999
# \questionnaire\disease\bladder_cancer_self_report\          4483
# \questionnaire\disease\lymphoma_self_report\                4485
# \questionnaire\disease\soft_cancer_self_report\             4478
# \questionnaire\disease\Any cancer or malignancy?\           4886
# \questionnaire\disease\chronic_disease_count\               9999
# \questionnaire\disease\leukemia_self_report\                4481
# \questionnaire\disease\gallbladder_cancer_self_...          4476
# \questionnaire\disease\liver_cancer_self_report\            4478
# \questionnaire\disease\Ever arthritis?\                     4886
# \questionnaire\disease\blood_cancer_self_report\            4476
# \questionnaire\disease\ovarian_cancer_self_report\          4491
# \questionnaire\disease\Any family with heart at...          4765
# \questionnaire\disease\Current asthma?\                     8971
# \questionnaire\disease\Ever osteo arthritis?\               4015
# \questionnaire\disease\prostate_cancer_self_rep...          4546
# \questionnaire\disease\melanoma_self_report\                4496
# \questionnaire\disease\colon_cancer_self_report\            4508
# \questionnaire\disease\thyroid_cancer_self_report\          4486
# \questionnaire\disease\uterine_cancer_self_report\          4496
# \questionnaire\disease\rectum_cancer_self_report\           4481
# \questionnaire\disease\pancreatic_cancer_self_r...          4476
#
#                                                     observationCount  \
# KEY
# \questionnaire\disease\any_cad\                                 4891
# \questionnaire\disease\skin_cancer_self_report\                 4542
# \questionnaire\disease\stomach_cancer_self_report\              4480
# \questionnaire\disease\brain_cancer_self_report\                4477
# \questionnaire\disease\other_cancer_self_report\                4494
# \questionnaire\disease\Any CAD (self report)\                   4859
# \questionnaire\disease\larynx_cancer_self_report\               4481
# \questionnaire\disease\mouth_cancer_self_report\                4477
# \questionnaire\disease\Any Diabetes (FBG >= 126...              9451
# \questionnaire\disease\esophagus_cancer_self_re...              4477
# \questionnaire\disease\other_skin_cancer_self_r...              4514
# \questionnaire\disease\Ever asthma?\                            9499
# \questionnaire\disease\testis_cancer_self_report\               4479
# \questionnaire\disease\cervix_cacner_self_report\               4504
# \questionnaire\disease\Ever rheumatoid arthritis?\              3911
# \questionnaire\disease\kidney_cancer_self_report\               4484
# \questionnaire\disease\lung_cancer_self_report\                 4486
# \questionnaire\disease\nervous_cancer_self_report\              4476
# \questionnaire\disease\breast_cancer_self_report\               4546
# \questionnaire\disease\                                         1195
# \questionnaire\disease\Any Hypertension? (BP >=...              5997
# \questionnaire\disease\bone_cancer_self_report\                 4483
# \questionnaire\disease\any_chronic_disease\                     9999
# \questionnaire\disease\bladder_cancer_self_report\              4483
# \questionnaire\disease\lymphoma_self_report\                    4485
# \questionnaire\disease\soft_cancer_self_report\                 4478
# \questionnaire\disease\Any cancer or malignancy?\               4886
# \questionnaire\disease\chronic_disease_count\                   9999
# \questionnaire\disease\leukemia_self_report\                    4481
# \questionnaire\disease\gallbladder_cancer_self_...              4476
# \questionnaire\disease\liver_cancer_self_report\                4478
# \questionnaire\disease\Ever arthritis?\                         4886
# \questionnaire\disease\blood_cancer_self_report\                4476
# \questionnaire\disease\ovarian_cancer_self_report\              4491
# \questionnaire\disease\Any family with heart at...              4765
# \questionnaire\disease\Current asthma?\                         8971
# \questionnaire\disease\Ever osteo arthritis?\                   4015
# \questionnaire\disease\prostate_cancer_self_rep...              4546
# \questionnaire\disease\melanoma_self_report\                    4496
# \questionnaire\disease\colon_cancer_self_report\                4508
# \questionnaire\disease\thyroid_cancer_self_report\              4486
# \questionnaire\disease\uterine_cancer_self_report\              4496
# \questionnaire\disease\rectum_cancer_self_report\               4481
# \questionnaire\disease\pancreatic_cancer_self_r...              4476
#
#                                                    HpdsDataType   min  \
# KEY
# \questionnaire\disease\any_cad\                      phenotypes   NaN
# \questionnaire\disease\skin_cancer_self_report\      phenotypes   NaN
# \questionnaire\disease\stomach_cancer_self_report\   phenotypes   NaN
# \questionnaire\disease\brain_cancer_self_report\     phenotypes   NaN
# \questionnaire\disease\other_cancer_self_report\     phenotypes   NaN
# \questionnaire\disease\Any CAD (self report)\        phenotypes   NaN
# \questionnaire\disease\larynx_cancer_self_report\    phenotypes   NaN
# \questionnaire\disease\mouth_cancer_self_report\     phenotypes   NaN
# \questionnaire\disease\Any Diabetes (FBG >= 126...   phenotypes   NaN
# \questionnaire\disease\esophagus_cancer_self_re...   phenotypes   NaN
# \questionnaire\disease\other_skin_cancer_self_r...   phenotypes   NaN
# \questionnaire\disease\Ever asthma?\                 phenotypes   NaN
# \questionnaire\disease\testis_cancer_self_report\    phenotypes   NaN
# \questionnaire\disease\cervix_cacner_self_report\    phenotypes   NaN
# \questionnaire\disease\Ever rheumatoid arthritis?\   phenotypes   NaN
# \questionnaire\disease\kidney_cancer_self_report\    phenotypes   NaN
# \questionnaire\disease\lung_cancer_self_report\      phenotypes   NaN
# \questionnaire\disease\nervous_cancer_self_report\   phenotypes   0.0
# \questionnaire\disease\breast_cancer_self_report\    phenotypes   NaN
# \questionnaire\disease\                              phenotypes  12.8
# \questionnaire\disease\Any Hypertension? (BP >=...   phenotypes   NaN
# \questionnaire\disease\bone_cancer_self_report\      phenotypes   NaN
# \questionnaire\disease\any_chronic_disease\          phenotypes   NaN
# \questionnaire\disease\bladder_cancer_self_report\   phenotypes   NaN
# \questionnaire\disease\lymphoma_self_report\         phenotypes   NaN
# \questionnaire\disease\soft_cancer_self_report\      phenotypes   NaN
# \questionnaire\disease\Any cancer or malignancy?\    phenotypes   NaN
# \questionnaire\disease\chronic_disease_count\        phenotypes   0.0
# \questionnaire\disease\leukemia_self_report\         phenotypes   NaN
# \questionnaire\disease\gallbladder_cancer_self_...   phenotypes   0.0
# \questionnaire\disease\liver_cancer_self_report\     phenotypes   NaN
# \questionnaire\disease\Ever arthritis?\              phenotypes   NaN
# \questionnaire\disease\blood_cancer_self_report\     phenotypes   NaN
# \questionnaire\disease\ovarian_cancer_self_report\   phenotypes   NaN
# \questionnaire\disease\Any family with heart at...   phenotypes   NaN
# \questionnaire\disease\Current asthma?\              phenotypes   NaN
# \questionnaire\disease\Ever osteo arthritis?\        phenotypes   NaN
# \questionnaire\disease\prostate_cancer_self_rep...   phenotypes   NaN
# \questionnaire\disease\melanoma_self_report\         phenotypes   NaN
# \questionnaire\disease\colon_cancer_self_report\     phenotypes   NaN
# \questionnaire\disease\thyroid_cancer_self_report\   phenotypes   NaN
# \questionnaire\disease\uterine_cancer_self_report\   phenotypes   NaN
# \questionnaire\disease\rectum_cancer_self_report\    phenotypes   NaN
# \questionnaire\disease\pancreatic_cancer_self_r...   phenotypes   NaN
#
#                                                               max
# KEY
# \questionnaire\disease\any_cad\                               NaN
# \questionnaire\disease\skin_cancer_self_report\               NaN
# \questionnaire\disease\stomach_cancer_self_report\            NaN
# \questionnaire\disease\brain_cancer_self_report\              NaN
# \questionnaire\disease\other_cancer_self_report\              NaN
# \questionnaire\disease\Any CAD (self report)\                 NaN
# \questionnaire\disease\larynx_cancer_self_report\             NaN
# \questionnaire\disease\mouth_cancer_self_report\              NaN
# \questionnaire\disease\Any Diabetes (FBG >= 126...            NaN
# \questionnaire\disease\esophagus_cancer_self_re...            NaN
# \questionnaire\disease\other_skin_cancer_self_r...            NaN
# \questionnaire\disease\Ever asthma?\                          NaN
# \questionnaire\disease\testis_cancer_self_report\             NaN
# \questionnaire\disease\cervix_cacner_self_report\             NaN
# \questionnaire\disease\Ever rheumatoid arthritis?\            NaN
# \questionnaire\disease\kidney_cancer_self_report\             NaN
# \questionnaire\disease\lung_cancer_self_report\               NaN
# \questionnaire\disease\nervous_cancer_self_report\  4.940656e-324
# \questionnaire\disease\breast_cancer_self_report\             NaN
# \questionnaire\disease\                              5.279000e+02
# \questionnaire\disease\Any Hypertension? (BP >=...            NaN
# \questionnaire\disease\bone_cancer_self_report\               NaN
# \questionnaire\disease\any_chronic_disease\                   NaN
# \questionnaire\disease\bladder_cancer_self_report\            NaN
# \questionnaire\disease\lymphoma_self_report\                  NaN
# \questionnaire\disease\soft_cancer_self_report\               NaN
# \questionnaire\disease\Any cancer or malignancy?\             NaN
# \questionnaire\disease\chronic_disease_count\        4.000000e+00
# \questionnaire\disease\leukemia_self_report\                  NaN
# \questionnaire\disease\gallbladder_cancer_self_...  4.940656e-324
# \questionnaire\disease\liver_cancer_self_report\              NaN
# \questionnaire\disease\Ever arthritis?\                       NaN
# \questionnaire\disease\blood_cancer_self_report\              NaN
# \questionnaire\disease\ovarian_cancer_self_report\            NaN
# \questionnaire\disease\Any family with heart at...            NaN
# \questionnaire\disease\Current asthma?\                       NaN
# \questionnaire\disease\Ever osteo arthritis?\                 NaN
# \questionnaire\disease\prostate_cancer_self_rep...            NaN
# \questionnaire\disease\melanoma_self_report\                  NaN
# \questionnaire\disease\colon_cancer_self_report\              NaN
# \questionnaire\disease\thyroid_cancer_self_report\            NaN
# \questionnaire\disease\uterine_cancer_self_report\            NaN
# \questionnaire\disease\rectum_cancer_self_report\             NaN
# \questionnaire\disease\pancreatic_cancer_self_r...            NaN  >

# %% [markdown]
# # Problem 2

# %% [markdown]
# Use count queries to confirm the well known relationship between BMI and blood pressure.

# %%
age_groups={'group_names':["infrant", "toddler","tyke","teen","adult","senior"],
           'min_age':[0,3,8,11,21,45],'max_age':[2,7,10,20,44,150]}
q2criteria.extend(d.find("BP").keys())
q2criteria.extend(d.find("\\Body Mass Index").keys())

copdgene_dic = resource.dictionary().find("disease").DataFrame()
consent_dic = resource.dictionary().find("AGE").DataFrame()
plain_variablesDict = resource.dictionary().find("Disease").DataFrame()
plain_variablesDict = resource.dictionary().find().DataFrame()
variablesDict = get_multiIndex_variablesDict(plain_variablesDict)
d = resource.dictionary()
q1criteria = []
q1query_unified = list()

my_query = resource.query()
#my_query.filter().add(gender_concept_path, "male")
my_query.filter().add(diseasedf,age_groups)
my_query.filter().add(agedf, age_groups)
q1criteria.extend(d.find("disease").keys())
q1criteria.extend(d.find("\\disease\\lung_cancer_self_report").keys())
q1criteria.extend(d.find("\\disease\\Current asthma?").keys())
q1criteria.extend(d.find("\\disease\\Ever asthma?").keys())
q1criteria.extend(d.find("AGE").keys())
my_query.require().add(q1criteria)
df_mf = query_unified.getResultsDataFrame()
df_mf

measuredf = resource.dictionary().find("body measures").DataFrame()
measuredf[measuredf.categorical == False]
body_measure_concept_path = measuredf.index[0]
body_measure_concept_path

fullVariableDict = resource.dictionary().find("body measures")
body_measure_df=fullVariableDict.DataFrame()
variablesDict = get_multiIndex_variablesDict(body_measure_df)
mask_measure = variablesDict.index.get_level_values(1) == "body measures"
mask_bmi = variablesDict.index.get_level_values(1) == "Body Mass Index"
mask_pf= variablesDict.index.get_level_values(1) == "\\examination\\body measures\\physical fitness"
mask_bp = variablesDict.index.get_level_values(1) == "\\examination\\physical fitness\\blood pressure"
heart_disease_variables = variablesDict.loc[mask_bmi | ~mask_bp ,:]
heart_disease_variables
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'categoryValues'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1064-9bd73ab1d2c2> in <module>
#       6 fullVariableDict = resource.dictionary().find("body measures")
#       7 body_measure_df=fullVariableDict.DataFrame()
# ----> 8 variablesDict = get_multiIndex_variablesDict(body_measure_df)
#       9 mask_measure = variablesDict.index.get_level_values(1) == "body measures"
#      10 mask_bmi = variablesDict.index.get_level_values(1) == "Body Mass Index"
#
# ~/work/python_lib/utils.py in get_multiIndex_variablesDict(variablesDict)
#      32     variablesDict = variablesDict.reset_index(drop=False)
#      33     variablesDict.index = multi_index.rename(["level_" + str(n) for n, _ in enumerate(multi_index.names)])
# ---> 34     variablesDict["nb_modalities"] = list(_get_number_modalities(variablesDict["categoryValues"]))
#      35     variablesDict["simplified_name"] = last_valid_name_list
#      36     columns_order = ["simplified_name", "name", "observationCount", "categorical", "categoryValues", "nb_modalities", "min", "max", "HpdsDataType"]
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'categoryValues'

# %%
heart_disease_variables

# %% [markdown]
# # Problem 3

# %% [markdown]
# Use count queries to show comorbidities between different types of disease. The concept paths related to disease status of each participant are prefixed with "\\questionnaire\\disease\\". There are 44 such disease status concept paths and all are categorical concepts.

# %%
qdisdf = dictionary.find("\\questionnaire\\disease").DataFrame()
qdisdf=dictionary.find("disease").DataFrame()
qdisdf[qdisdf.categorical == True]
qdisdf.keys

# %%
bmidf = resource.dictionary().find("BMI").DataFrame()
bpdf = resource.dictionary().find("BP").DataFrame()
